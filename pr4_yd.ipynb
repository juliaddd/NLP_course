# %% [markdown]
# # **Natural Language Processing**
# ## *Practice 4 - Entity Recognition*

# %% [markdown]
# ## Objectives
#
# * Learn to identify and classify the entities of a text using the ***spaCy*** library.

# %% [markdown]
# ## Entity recognition
#
# The goal of an entity recognition system, also known as "NER system" (*Named Entity Recognition system*), is to identify and classify in predefined categories (person, organization, etc.) the entities found in a text. Entity recognition is usually divided into two subtasks: entity detection and identification of the type of detected entities.
#
# This task can be useful, among other things, to improve the accuracy of Answer Search systems by returning to the user the text fragment that contains an answer to his question instead of returning the whole text, etc.
#
# For this practice we will make use of the [***spaCy***](https://spacy.io/usage/linguistic-features#named-entities) library and its automatic entity recognizer using as always a pre-trained model:

# %%
import spacy
import en_core_web_sm

nlp = en_core_web_sm.load()

# %%
sentence = 'European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices.'

# %%
doc = nlp(sentence)

# %% [markdown]
# We can see the type of each entity by navigating through the *doc*:

# %%
for word in doc:
    print(word.text, word.ent_type_)
# Out:
# European NORP
# authorities
# fined
# Google ORG
# a
# record
# $ MONEY
# 5.1 MONEY
# billion MONEY
# on
# Wednesday DATE
# for
# abusing
# its
# power
# in
# the
# mobile
# phone
# market
# and
# ordered
# the
# company
# to
# alter
# its
# practices
# .

# %% [markdown]
# As we can appreciate, the entity *European* is of type **NORD** (nationalities or religious or political groups), *Google* is an organization (**ORG**), *$5.1 billion* is the monetary value (**MONEY**) and *Wednesday* is a date object (**DATE**).

# %% [markdown]
# But it seems that it is not very clear when tokenizing the sentence since an entity can be composed of several words ($5.1 billion).
#
# In entity recognition there is a word-level tagging scheme called BIO-tagging (Begin-Inside-Outside). So, "B" means the token starts an entity, "I" means it is inside an entity, and "O" means it is outside an entity. Let's see an example:

# %%
for word in doc:
    print(word.text, word.ent_iob_, word.ent_type_)
# Out:
# European B NORP
# authorities O
# fined O
# Google B ORG
# a O
# record O
# $ B MONEY
# 5.1 I MONEY
# billion I MONEY
# on O
# Wednesday B DATE
# for O
# abusing O
# its O
# power O
# in O
# the O
# mobile O
# phone O
# market O
# and O
# ordered O
# the O
# company O
# to O
# alter O
# its O
# practices O
# . O

# %% [markdown]
# To display only the entities and also to see the entities composed of several words, we can use the **ents** attribute of the doc:

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# European NORP
# Google ORG
# $5.1 billion MONEY
# Wednesday DATE

# %% [markdown]
# Also, we can see through the display the entities visually:

# %%
from spacy import displacy

# %%
displacy.render(doc, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     European
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  authorities fined
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  a record
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $5.1 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  for abusing its power in the mobile phone market and ordered the company to alter its practices.</div></span>

# %% [markdown]
# Depending on the model used, there are different entity categories, for example, using the "*en_core_web_sm*" model, the existing entities are:
#
# *   PERSON People, including fictional.
# *   NORP Nationalities or religious or political groups.
# *   FAC Buildings, airports, highways, bridges, etc.
# *   ORG Companies, agencies, institutions, etc.
# *   GPE  Geopolitical entities including countries, cities, states.
# *   LOC Non-GPE locations, mountain ranges, bodies of water.
# *   PRODUCT Objects, vehicles, foods, etc. (Not services.)
# *   EVENT Named hurricanes, battles, wars, sports events, etc.
# *   WORK_OF_ART Titles of books, songs, etc.
# *   LAW Named documents made into laws.
# *   LANGUAGE Any named language.
# *   DATE Absolute or relative dates or periods.
# *   TIME Times smaller than a day.
# *   etc...

# %% [markdown]
# ## Exercises
#
# The result of this practice must be submited by PLATEA and its deadline is **23:59 hours on March 17th, 2025**. This same notebook with extension *.ipynb* will be submitted and renamed as follows: pr5_user1_user2.ipynb. Replace "user1" and "user2" with your email alias.
#
# Download the file "nyt.txt" which is available in Docencia Virtual (Material Complementario folder) and carry out the following tasks:

# %% [markdown]
# ### Exercise 1
#
# Extract for each category the entities present in the text and their frequency of occurrence (taking into account multi-words), and answer the following questions:
# - From the entities extracted, indicate in brief what the news seems to be about.
# - Which two people are the most mentioned in the news?
# - What are the three most referenced geopolitical entities?

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path ='/content/drive/MyDrive/NLP/nyt.txt'

# %%
import spacy
import en_core_web_sm

nlp = en_core_web_sm.load()

with open(file_path, 'r', encoding='cp1252') as file:
    text = file.read()

doc = nlp(text)

# %% [markdown]
# All entities in the text:

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# WASHINGTON GPE
# nearly four years ago DATE
# Abdel Fattah PERSON
# Egypt GPE
# the White House ORG
# Trump PERSON
# Monday DATE
# Sisi PERSON
# Trump ORG
# Sisi PERSON
# the Oval Office FAC
# el-Sisi PERSON
# Egypt GPE
# Egypt GPE
# The United States GPE
# one CARDINAL
# Trump ORG
# American NORP
# Sisi PERSON
# Trump ORG
# Egypt GPE
# Trump ORG
# the United States GPE
# Sisi NORP
# Cairo GPE
# the six minutes TIME
# the Oval Office FAC
# Barack Obama PERSON
# the White House ORG
# American NORP
# Sisi PERSON
# Eric Trager PERSON
# Egypt GPE
# the Washington Institute for Near East Policy ORG
# the White House ORG
# Sisi’s ORG
# Egypt GPE
# hundreds CARDINAL
# Cairo GPE
# first ORDINAL
# Egyptian NORP
# Washington GPE
# 2009 DATE
# Hosni Mubarak PERSON
# the waning years DATE
# Egyptians NORP
# Mubarak PERSON
# 2011 DATE
# the Muslim Brotherhood’s ORG
# Mohamed Morsi ORG
# Morsi PERSON
# two years later DATE
# Sisi PERSON
# Sisi NORP
# 97 percent PERCENT
# Trump ORG
# America GPE
# Middle Eastern LOC
# Monday DATE
# Trump ORG
# the United States GPE
# Trump ORG
# Sisi PERSON
# Sisi PERSON
# Trumpian NORP
# Egypt GPE
# Trump ORG
# Israelis NORP
# Palestinians NORP
# the century DATE
# the century DATE
# Egypt GPE
# American NORP
# the Middle East LOC
# Trump ORG
# Sisi NORP
# Vladimir V. Putin PERSON
# Russia GPE
# first ORDINAL
# September DATE
# the United Nations General Assembly ORG
# Trump ORG
# Sisi PERSON
# Egypt GPE
# Trump ORG
# Fox Business Network ORG
# Sisi PERSON
# The Financial Times ORG
# December DATE
# Egyptians NORP
# Cairo GPE
# Trump ORG
# Monday DATE
# Cairo GPE
# 17 CARDINAL
# five years DATE
# January 2015 DATE
# Rome GPE
# Giulio Regeni PERSON
# Italian NORP
# Cairo GPE
# last year DATE
# Egyptian NORP
# Alessandra Ballerini PERSON
# two CARDINAL
# Egyptian NORP
# jihadist NORP
# Islam NORP
# Trump ORG
# Sisi ORG
# Egypt GPE
# Middle East LOC
# the Suez Canal for   ORG
# Sisi PERSON
# Mexico GPE
# Trump ORG
# Egyptians NORP
# Sisi PERSON
# Arabic LANGUAGE
# Trump ORG
# fifth ORDINAL
# one CARDINAL
# last year DATE
# recent months DATE
# Trump ORG
# American NORP
# last year DATE
# Sisi NORP
# Egyptians NORP
# Trump ORG
# Republican NORP
# Sisi ORG
# dozens CARDINAL
# China GPE
# Turkey GPE
# Parliament ORG
# two CARDINAL
# Sisi ORG
# Aya Hijazi PERSON
# American NORP
# Egypt GPE
# Trump ORG
# White House ORG
# Egypt GPE
# $1.3 billion MONEY
# Trump ORG
# Muslim Brotherhood ORG
# Trump ORG
# Hijazi PERSON
# United States GPE
# Wade McMullen PERSON
# Robert F. Kennedy Human Rights ORG
# One CARDINAL
# Sisi NORP
# Western NORP
# Cairo GPE
# Trump ORG
# Obama LOC
# 2015 DATE
# Egypt GPE
# Sisi NORP
# American NORP
# American NORP
# Egypt GPE
# Islamic NORP
# Sinai GPE
# Trump PERSON
# Egyptians NORP
# Islam ORG
# Amy Hawthorne PERSON
# Middle East Democracy LOC
# Washington GPE
# Sisi NORP
# Sisi PERSON
# Islamism NORP
# Islam NORP
# the Muslim Brotherhood ORG
# jihadist NORP
# the United States GPE
# U.S. GPE
# Egypt GPE
# Hawthorne PERSON
# U.S. GPE

# %% [markdown]
# Amount of entities of each category

# %%
entity_frequencies = {}
for ent in doc.ents:
    if ent.label_ in entity_frequencies:
        entity_frequencies[ent.label_].append(ent.text)
    else:
        entity_frequencies[ent.label_] = [ent.text]

for entity_type, entities in entity_frequencies.items():
    print(f"Entity Type: {entity_type} - {len(entities)}")
# Out:
# Entity Type: GPE - 38
# Entity Type: DATE - 19
# Entity Type: PERSON - 29
# Entity Type: ORG - 41
# Entity Type: FAC - 2
# Entity Type: CARDINAL - 8
# Entity Type: NORP - 34
# Entity Type: TIME - 1
# Entity Type: ORDINAL - 3
# Entity Type: PERCENT - 1
# Entity Type: LOC - 5
# Entity Type: LANGUAGE - 1
# Entity Type: MONEY - 1

# %% [markdown]
# Frequency of each entity

# %%
from collections import Counter

for entity_type, entities in entity_frequencies.items():
    print(f"Entity Type: {entity_type}")
    entity_counts = Counter(entities)
    for entity, frequency in entity_counts.items():
        print(f"  {entity}: {frequency}")
# Out:
# Entity Type: GPE
#   WASHINGTON: 1
#   Egypt: 15
#   The United States: 1
#   the United States: 3
#   Cairo: 6
#   Washington: 2
#   America: 1
#   Russia: 1
#   Rome: 1
#   Mexico: 1
#   China: 1
#   Turkey: 1
#   United States: 1
#   Sinai: 1
#   U.S.: 2
# Entity Type: DATE
#   nearly four years ago: 1
#   Monday: 3
#   2009: 1
#   the waning years: 1
#   2011: 1
#   two years later: 1
#   the century: 2
#   September: 1
#   December: 1
#   five years: 1
#   January 2015: 1
#   last year: 3
#   recent months: 1
#   2015: 1
# Entity Type: PERSON
#   Abdel Fattah: 1
#   Trump: 2
#   Sisi: 12
#   el-Sisi: 1
#   Barack Obama: 1
#   Eric Trager: 1
#   Hosni Mubarak: 1
#   Mubarak: 1
#   Morsi: 1
#   Vladimir V. Putin: 1
#   Giulio Regeni: 1
#   Alessandra Ballerini: 1
#   Aya Hijazi: 1
#   Hijazi: 1
#   Wade McMullen: 1
#   Amy Hawthorne: 1
#   Hawthorne: 1
# Entity Type: ORG
#   the White House: 3
#   Trump: 21
#   the Washington Institute for Near East Policy: 1
#   Sisi’s: 1
#   the Muslim Brotherhood’s: 1
#   Mohamed Morsi: 1
#   the United Nations General Assembly: 1
#   Fox Business Network: 1
#   The Financial Times: 1
#   Sisi: 3
#   the Suez Canal for  : 1
#   Parliament: 1
#   White House: 1
#   Muslim Brotherhood: 1
#   Robert F. Kennedy Human Rights: 1
#   Islam: 1
#   the Muslim Brotherhood: 1
# Entity Type: FAC
#   the Oval Office: 2
# Entity Type: CARDINAL
#   one: 2
#   hundreds: 1
#   17: 1
#   two: 2
#   dozens: 1
#   One: 1
# Entity Type: NORP
#   American: 7
#   Sisi: 7
#   Egyptian: 3
#   Egyptians: 5
#   Trumpian: 1
#   Israelis: 1
#   Palestinians: 1
#   Italian: 1
#   jihadist: 2
#   Islam: 2
#   Republican: 1
#   Western: 1
#   Islamic: 1
#   Islamism: 1
# Entity Type: TIME
#   the six minutes: 1
# Entity Type: ORDINAL
#   first: 2
#   fifth: 1
# Entity Type: PERCENT
#   97 percent: 1
# Entity Type: LOC
#   Middle Eastern: 1
#   the Middle East: 1
#   Middle East: 1
#   Obama: 1
#   Middle East Democracy: 1
# Entity Type: LANGUAGE
#   Arabic: 1
# Entity Type: MONEY
#   $1.3 billion: 1

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

nltk.download('wordnet')
nltk.download('stopwords')

nlp = en_core_web_sm.load()
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess_text(text):
  tokens = [lemmatizer.lemmatize(token) for token in text.split() if token not in stop_words]  # Lemmatization and stop word removal
  return " ".join(tokens)

preprocessed_text = preprocess_text(text)

doc = nlp(preprocessed_text)

entity_frequencies = {}

for ent in doc.ents:
    if ent.label_ in entity_frequencies:
        entity_frequencies[ent.label_].append(ent.text)
    else:
        entity_frequencies[ent.label_] = [ent.text]


for entity_type, entities in entity_frequencies.items():
    print(f"Entity Type: {entity_type}")
    entity_counts = Counter(entities)
    for entity, frequency in entity_counts.most_common(5):  # Get top 5
        print(f"  {entity}: {frequency}")
# Out:
# Entity Type: GPE
#   Egypt: 15
#   Cairo: 6
#   United States: 4
#   Washington: 2
#   U.S.: 2
# Entity Type: DATE
#   Monday: 3
#   last year: 3
#   nearly four year ago: 1
#   2009: 1
#   year: 1
# Entity Type: PERSON
#   Sisi: 8
#   Trump: 2
#   Abdel Fattah: 1
#   el-Sisi: 1
#   Barack Obama: 1
# Entity Type: ORG
#   Trump: 19
#   Sisi: 6
#   White House: 4
#   Islam: 3
#   Muslim Brotherhood: 2
# Entity Type: CARDINAL
#   one: 2
#   two: 2
#   hundred: 1
#   17: 1
#   dozen: 1
# Entity Type: NORP
#   American: 7
#   Sisi: 5
#   Egyptians: 5
#   Egyptian: 3
#   jihadist: 2
# Entity Type: TIME
#   six minute: 1
# Entity Type: ORDINAL
#   first: 2
#   fifth: 1
# Entity Type: PERCENT
#   97 percent: 1
# Entity Type: LOC
#   Middle East: 2
#   Middle Eastern: 1
#   Middle East Democracy: 1
# Entity Type: FAC
#   part street: 1
# Entity Type: MONEY
#   $1.3 billion: 1

# %% [markdown]
# - From this we can understand that the news are about the relationship between Egypt (under President Sisi) and the United States (under President Trump). There might be mentions of economic aid or political strategies involving the Middle East. The presence of "Islam" and "Muslim Brotherhood" suggests a possible focus on religious or political groups within Egypt
#
# - Two most mentiont people: **Egyptian President Abdel Fattah el-Sisi**  and **U.S. President Donald Trump**.
#
# - Top 3 GPE: Egypt, Cairo, United States.

# %% [markdown]
# ### Exercise 2
#
# Considering the BIO labeling system, indicate how many entities of type PERSON appear with only one word.

# %%
for word in doc:
  if word.ent_type_ == "PERSON":
    print(word.text, word.ent_iob_)
# Out:
# Abdel B
# Fattah I
# Trump B
# Sisi B
# el B
# - I
# Sisi I
# Sisi B
# Barack B
# Obama I
# Eric B
# Trager I
# Sisi B
# Hosni B
# Mubarak I
# Mubarak B
# Morsi B
# Sisi B
# pro B
# forma I
# Sisi B
# Vladimir B
# V. I
# Putin I
# Russia I
# Sisi B
# Giulio B
# Regeni I
# Alessandra B
# Ballerini I
# Suez B
# Canal I
# Sisi I
# Sisi B
# Aya B
# Hijazi I
# Hijazi B
# Wade B
# McMullen I
# Robert B
# F. I
# Kennedy I
# Obama B
# 2015 I
# warplane B
# large I
# - I
# Trump B
# Amy B
# Hawthorne I
# Sisi B
# Hawthorne B

# %%
single_word_person_count = 0

for ent in doc.ents:
    if ent.label_ == "PERSON":
        if len(ent) == 1:
            single_word_person_count += 1

print(f"Number of single-word PERSON entities: {single_word_person_count}")
# Out:
# Number of single-word PERSON entities: 14

# %% [markdown]
# ### Exercise 3
#
# You have to select all the sentences with PERSON entities, which you extracted in **exercise 2**, and to make the following actions:
#
# 1. To identify the main verb.
# 2. To count the number of verbs, adjectives and adverbs.
# 3. To desambiguate the verbs, adjectives and adverbs with WordNet. You have to show the synsets and its gloss.

# %%
with open(file_path, 'r', encoding='cp1252') as file:
    text = file.read()

doc = nlp(text)

# %%
sentences_with_person_entities = []
for sentence in doc.sents:
  for ent in sentence.ents:
    if ent.label_ == "PERSON":
      sentences_with_person_entities.append(sentence)
      break

# %%
from spacy import displacy
displacy.render(sentences_with_person_entities, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     WASHINGTON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  — Ever since he seized power in a military takeover
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly four years ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Abdel Fattah
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  el-Sisi of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Egypt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has been barred from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the White House
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">But President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  made clear on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that the period of ostracism was over as he hosted
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sisi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and pledged unstinting support for the autocratic ruler.<br><br></div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said as he sat beside
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sisi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Oval Office
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">“I just want to let everybody know in case there was any doubt that we are very much behind President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     el-Sisi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">While his predecessors considered authoritarians like
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sisi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to be distasteful and at times shied away from them,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  signaled that he sees international relations through a transactional lens. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">He arrived from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cairo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  with a list of financial, security and political requests, but effectively he got what he really wanted in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the six minutes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  that news media photographers were permitted in
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Oval Office
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  to record the visit that President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barack Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  had denied him. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">That big hug was just what
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sisi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s government sought, said
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eric Trager
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a scholar on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Egypt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Washington Institute for Near East Policy
#     <span style="font-size: 0.8em; font-we

# %% [markdown]
# - To identify the main verb.
#
# - To count the number of verbs, adjectives and adverbs.
# -
# To desambiguate the verbs, adjectives and adverbs with WordNet. You have to show the synsets and its gloss.

# %%
import spacy
spacy.cli.download("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import re

filtered_sentences = []
for sentence in sentences_with_person_entities:
    cleaned_sentence = re.sub(r'[\x00-\x1f\x7f-\x9f]+', '', sentence.text)
    if cleaned_sentence.strip():
        filtered_sentences.append(cleaned_sentence)

# %%
for sentence in filtered_sentences:
  doc = nlp(sentence)
  print(f"Sentence: {sentence}")
  main_verb = None
  for token in doc:
    if token.pos_ == "VERB" and token.dep_== "ROOT":
      main_verb = token.text
      break
  if main_verb:
    print(f"Main Verb: {main_verb}")
  else  :
    print("No main verb found\n")
# Out:
# Sentence: WASHINGTON — Ever since he seized power in a military takeover nearly four years ago, President Abdel Fattah el-Sisi of Egypt has been barred from the White House.
# Main Verb: barred
# Sentence: But President Trump made clear on Monday that the period of ostracism was over as he hosted  Sisi and pledged unstinting support for the autocratic ruler.
# Main Verb: made
# Sentence: Trump said as he sat beside  Sisi in the Oval Office.
# Main Verb: said
# Sentence: “I just want to let everybody know in case there was any doubt that we are very much behind President el-Sisi.
# Main Verb: want
# Sentence: While his predecessors considered authoritarians like  Sisi to be distasteful and at times shied away from them,  Trump signaled that he sees international relations through a transactional lens.
# Main Verb: signaled
# Sentence: He arrived from Cairo with a list of financial, security and political requests, but effectively he got what he really wanted in the six minutes that news media photographers were permitted in the Oval Office to record the visit that President Barack Obama had denied him.
# Main Verb: arrived
# Sentence: That big hug was just what  Sisi’s government sought, said Eric Trager, a scholar on Egypt at the Washington Institute for Near East Policy.
# Main Verb: said
# Sentence: It was the first visit by an Egyptian president to Washington since 2009, when the guest was the autocratic former president Hosni Mubarak, then in the waning years of his rule — an era now viewed by many Egyptians as a time of relative freedom, prosperity and security.
# No main verb found
#
# Sentence: Mubarak was pushed out in 2011 by a wave of street protests and succeeded, in a democratic election, by the Muslim Brotherhood’s Mohamed Morsi.
# Main Verb: pushed
# Sentence: Taking advantage of popular discontent with  Morsi two years later, the military, led by  Sisi, then a general, took power and
# Main Verb: took
# Sentence: “I just want to say to you,  President, that you have a great friend and ally in the United States and in me,”  Trump told  Sisi.
# Main Verb: told
# Sentence: Sisi responded in kind, sometimes in language mimicking a Trumpian sales pitch.
# Main Verb: responded
# Sentence: While Egypt has long been a crucial American ally in the Middle East,  Trump’s admiration for  Sisi seems to mirror in some ways his appreciation for President Vladimir V. Putin of Russia as a fellow tough figure.
# Main Verb: seems
# Sentence: After their first meeting in September, on the sidelines of the United Nations General Assembly when  Trump was running for president, he hailed  Sisi as “a fantastic guy” and spoke admiringly of his iron-fisted methods.
# Main Verb: hailed
# Sentence: Sisi has rejected suggestions that he rules like a dictator.
# Main Verb: rejected
# Sentence: In Rome, the parents of Giulio Regeni, an Italian postgraduate student found dead in Cairo last year, held a news conference to press their longstanding accusations that Egyptian security officials had abducted, tortured and killed their son, probably on suspicion that he was a spy.
# Main Verb: held
# Sentence: The family’s lawyer, Alessandra Ballerini, said they had identified two high-ranking Egyptian national security officials said to be implicated in the case, but declined to give further details.
# Main Verb: said
# Sentence: Both leaders came to power promising splashy projects derided by experts — an expensive extension of the Suez Canal for  Sisi, and a giant wall along the Mexico border for  Trump.
# Main Verb: came
# Sentence: Egyptians also often mock  Sisi for speaking in a rustic form of Arabic that contrasts with the formal version usually favored by national leaders.
# Main Verb: mock
# Sentence: Sisi has resisted loud appeals to release Aya Hijazi, an American aid worker imprisoned in Egypt, while  Trump’s White House is considering slashing foreign aid to countries including Egypt’s $1.3 billion in military assistance.
# Main Verb: resisted
# Sentence: While human rights advocates criticized  Trump, a lawyer for Ms. Hijazi said her supporters had been working with his administration to highlight her case and those of others held.
# Main Verb: said
# Sentence: “We are confident that the case is being prioritized at the highest levels of the United States government,” said the lawyer, Wade McMullen, managing attorney at Robert F. Kennedy Human Rights, an advocacy center.
# Main Verb: said
# Sentence: “If Trump is really interested in getting the Egyptians to fight radical Islam, giving them more tanks will not help our goals,” said Amy Hawthorne of the Project on Middle East Democracy, a Washington nonprofit that has been sharply critical of  Sisi.
# Main Verb: said
# Sentence: Some experts worry that  Sisi’s hard-knuckled approach to Islamism — banning all forms of political Islam, such as the Muslim Brotherhood, as well as fighting jihadist violence — could ultimately feed a new wellspring of radicalism that could blow back on the United States.
# Main Verb: worry
# Sentence: “The authoritarian bargain the U.S. has struck with Egypt might seem to be the right thing, but it never pays off in the long run,” Ms. Hawthorne said.
# Main Verb: said

# %%
counter = 0
for sentence in filtered_sentences:
  counter += 1

  doc = nlp(sentence)
  print(f"Sentence {counter}: {sentence}")
  verb_count = 0
  adjective_count = 0
  adverb_count = 0
  for token in doc:
    if token.pos_ == "VERB":
      verb_count += 1
    elif token.pos_ == "ADJ":
      adjective_count += 1
    elif token.pos_ == "ADV":
      adverb_count += 1
  print(f"Verbs: {verb_count}, Adjectives: {adjective_count}, Adverbs: {adverb_count}")
# Out:
# Sentence 1: WASHINGTON — Ever since he seized power in a military takeover nearly four years ago, President Abdel Fattah el-Sisi of Egypt has been barred from the White House.
# Verbs: 2, Adjectives: 1, Adverbs: 3
# Sentence 2: But President Trump made clear on Monday that the period of ostracism was over as he hosted  Sisi and pledged unstinting support for the autocratic ruler.
# Verbs: 3, Adjectives: 3, Adverbs: 1
# Sentence 3: Trump said as he sat beside  Sisi in the Oval Office.
# Verbs: 2, Adjectives: 0, Adverbs: 0
# Sentence 4: “I just want to let everybody know in case there was any doubt that we are very much behind President el-Sisi.
# Verbs: 4, Adjectives: 0, Adverbs: 3
# Sentence 5: While his predecessors considered authoritarians like  Sisi to be distasteful and at times shied away from them,  Trump signaled that he sees international relations through a transactional lens.
# Verbs: 4, Adjectives: 3, Adverbs: 1
# Sentence 6: He arrived from Cairo with a list of financial, security and political requests, but effectively he got what he really wanted in the six minutes that news media photographers were permitted in the Oval Office to record the visit that President Barack Obama had denied him.
# Verbs: 6, Adjectives: 2, Adverbs: 2
# Sentence 7: That big hug was just what  Sisi’s government sought, said Eric Trager, a scholar on Egypt at the Washington Institute for Near East Policy.
# Verbs: 2, Adjectives: 1, Adverbs: 1
# Sentence 8: It was the first visit by an Egyptian president to Washington since 2009, when the guest was the autocratic former president Hosni Mubarak, then in the waning years of his rule — an era now viewed by many Egyptians as a time of relative freedom, prosperity and security.
# Verbs: 2, Adjectives: 6, Adverbs: 2
# Sentence 9: Mubarak was pushed out in 2011 by a wave of street protests and succeeded, in a democratic election, by the Muslim Brotherhood’s Mohamed Morsi.
# Verbs: 2, Adjectives: 1, Adverbs: 0
# Sentence 10: Taking advantage of popular discontent with  Morsi two years later, the military, led by  Sisi, then a general, took power and
# Verbs: 3, Adjectives: 1, Adverbs: 2
# Sentence 11: “I just want to say to you,  President, that you have a great friend and ally in the United States and in me,”  Trump told  Sisi.
# Verbs: 4, Adjectives: 1, Adverbs: 1
# Sentence 12: Sisi responded in kind, sometimes in language mimicking a Trumpian sales pitch.
# Verbs: 2, Adjectives: 1, Adverbs: 2
# Sentence 13: While Egypt has long been a crucial American ally in the Middle East,  Trump’s admiration for  Sisi seems to mirror in some ways his appreciation for President Vladimir V. Putin of Russia as a fellow tough figure.
# Verbs: 2, Adjectives: 4, Adverbs: 1
# Sentence 14: After their first meeting in September, on the sidelines of the United Nations General Assembly when  Trump was running for president, he hailed  Sisi as “a fantastic guy” and spoke admiringly of his iron-fisted methods.
# Verbs: 4, Adjectives: 2, Adverbs: 1
# Sentence 15: Sisi has rejected suggestions that he rules like a dictator.
# Verbs: 2, Adjectives: 0, Adverbs: 0
# Sentence 16: In Rome, the parents of Giulio Regeni, an Italian postgraduate student found dead in Cairo last year, held a news conference to press their longstanding accusations that Egyptian security officials had abducted, tortured and killed their son, probably on suspicion that he was a spy.
# Verbs: 6, Adjectives: 5, Adverbs: 1
# Sentence 17: The family’s lawyer, Alessandra Ballerini, said they had identified two high-ranking Egyptian national security officials said to be implicated in the case, but declined to give further details.
# Verbs: 7, Adjectives: 3, Adverbs: 1
# Sentence 18: Both leaders came to power promising splashy projects derided by experts — an expensive extension of the Suez Canal for  Sisi, and a giant wall along the Mexico border for  Trump.
# Verbs: 3, Adjectives: 3, Adverbs: 0
# Sentence 19: Egyptians also often mock  Sisi for speaking in a rustic form of Arabic that contrasts with the formal version usually favored by national leaders.
# Verbs: 4, Adjectives: 3, Adverbs: 3
# Sentence 20: Sisi has resisted loud appeals to release Aya Hijazi, an American aid worker imprisoned in Egypt, while  Trump’s White House is considering slashing foreign aid to countries including Egypt’s $1.3 billion in military assistance.
# Verbs: 6, Adjectives: 4, Adverbs: 0
# Sentence 21: While human rights advocates criticized  Trump, a lawyer for Ms. Hijazi said her supporters had been working with his administration to highlight her case and those of others held.
# Verbs: 5, Adjectives: 1, Adverbs: 0
# Sentence 22: “We are confident that the case is being prioritized at the highest levels of the United States government,” said the lawyer, Wade McMullen, managing attorney at Robert F. Kennedy Human Rights, an advocacy center.
# Verbs: 3, Adjectives: 2, Adverbs: 0
# Sentence 23: “If Trump is really interested in getting the Egyptians to fight radical Islam, giving them more tanks will not help our goals,” said Amy Hawthorne of the Project on Middle East Democracy, a Washington nonprofit that has been sharply critical of  Sisi.
# Verbs: 5, Adjectives: 4, Adverbs: 2
# Sentence 24: Some experts worry that  Sisi’s hard-knuckled approach to Islamism — banning all forms of political Islam, such as the Muslim Brotherhood, as well as fighting jihadist violence — could ultimately feed a new wellspring of radicalism that could blow back on the United States.
# Verbs: 6, Adjectives: 3, Adverbs: 5
# Sentence 25: “The authoritarian bargain the U.S. has struck with Egypt might seem to be the right thing, but it never pays off in the long run,” Ms. Hawthorne said.
# Verbs: 4, Adjectives: 3, Adverbs: 1

# %% [markdown]
# To desambiguate the verbs, adjectives and adverbs with WordNet. You have to show the synsets and its gloss.

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import wordnet as wn
def disambiguate_word(word, pos=None):

    # Map POS tags to WordNet POS tags
    pos_map = {
        'VERB': 'v',
        'ADJ': 'a',
        'ADV': 'r'
    }

    if pos:
        synsets = wn.synsets(word, pos=pos_map.get(pos))
    else:
        synsets = wn.synsets(word)

    if not synsets:
        print(f"\tNo synsets found for the word: {word}")
        return

    print(f"\n\tSynsets for '{word}' (POS: {pos if pos else 'any'}):")
    for i, synset in enumerate(synsets, 1):
        print(f"\t{i}. {synset.name()}: {synset.definition()}")
        # print(f"\t   Examples: {synset.examples()}\n")

# %%
counter = 0
for sentence in filtered_sentences:
  counter += 1

  doc = nlp(sentence)
  print(f"Sentence {counter}:")

  for token in doc:
    if token.pos_ == "VERB":
      disambiguate_word(token.text, "VERB")
    elif token.pos_ == "ADJ":
      disambiguate_word(token.text, "ADJ")
    elif token.pos_ == "ADV":
      disambiguate_word(token.text, "ADV")
# Out:
# Sentence 1:
#
# 	Synsets for 'Ever' (POS: ADV):
# 	1. ever.r.01: at any time
# 	2. always.r.01: at all times; all the time and on every occasion
# 	3. ever.r.03: (intensifier for adjectives) very
#
# 	Synsets for 'seized' (POS: VERB):
# 	1. seize.v.01: take hold of; grab
# 	2. seize.v.02: take or capture by force
# 	3. appropriate.v.02: take possession of by force, as after an invasion
# 	4. impound.v.01: take temporary possession of as a security, by legal authority
# 	5. assume.v.06: seize and take control without authority and possibly with force; take as one's right or possession
# 	6. seize.v.06: hook by a pull on the line
# 	7. seize.v.07: affect
# 	8. grab.v.06: capture the attention or imagination of
#
# 	Synsets for 'military' (POS: ADJ):
# 	1. military.a.01: of or relating to the study of the principles of warfare
# 	2. military.a.02: characteristic of or associated with soldiers or the military
# 	3. military.a.03: associated with or performed by members of the armed services as contrasted with civilians
#
# 	Synsets for 'nearly' (POS: ADV):
# 	1. about.r.07: (of actions or states) slightly short of or not quite accomplished; all but
# 	2. closely.r.03: in a close manner
#
# 	Synsets for 'ago' (POS: ADV):
# 	1. ago.r.01: in the past
#
# 	Synsets for 'barred' (POS: VERB):
# 	1. bar.v.01: prevent from entering; keep out
# 	2. barricade.v.01: render unsuitable for passage
# 	3. banish.v.03: expel, as if by official decree
# 	4. bar.v.04: secure with, or as if with, bars
# Sentence 2:
#
# 	Synsets for 'made' (POS: VERB):
# 	1. make.v.01: engage in
# 	2. make.v.02: give certain properties to something
# 	3. make.v.03: make or cause to be or to become
# 	4. induce.v.02: cause to do; cause to act in a specified manner
# 	5. cause.v.01: give rise to; cause to happen or occur, not always intentionally
# 	6. produce.v.02: create or manufacture a man-made product
# 	7. draw.v.04: make, formulate, or derive in the mind
# 	8. make.v.08: compel or make somebody or something to act in a certain way
# 	9. create.v.05: create by artistic means
# 	10. gain.v.08: earn on some commercial or business transaction; earn as salary or wages
# 	11. do.v.08: create or design, often in a certain way
# 	12. form.v.02: to compose or represent:
# 	13. reach.v.07: reach a goal, e.g.,
# 	14. make.v.14: be or be capable of being changed or made into
# 	15. make.v.15: make by shaping or bringing together constituents
# 	16. make.v.16: perform or carry out
# 	17. construct.v.01: make by combining materials and parts
# 	18. make.v.18: change from one form into another
# 	19. make.v.19: act in a certain way so as to acquire
# 	20. name.v.03: charge with a function; charge to be
# 	21. have.v.17: achieve a point or goal
# 	22. reach.v.01: reach a destination, either real or abstract
# 	23. lay_down.v.01: institute, enact, or establish
# 	24. make.v.24: carry out or commit
# 	25. make.v.25: form by assembling individuals or constituents
# 	26. hold.v.03: organize or be responsible for
# 	27. make.v.27: put in order or neaten
# 	28. take.v.27: head into a specified direction
# 	29. stool.v.04: have a bowel movement
# 	30. make.v.30: undergo fabrication or creation
# 	31. make.v.31: be suitable for
# 	32. make.v.32: add up to
# 	33. make.v.33: amount to
# 	34. make.v.34: constitute the essence of
# 	35. make.v.35: appear to begin an activity
# 	36. make.v.36: proceed along a path
# 	37. make.v.37: reach in time
# 	38. make.v.38: gather and light the materials for
# 	39. cook.v.02: prepare for eating by applying heat
# 	40. seduce.v.01: induce to have sex
# 	41. make.v.41: assure the success of
# 	42. make.v.42: represent fictitiously, as in a play, or pretend to be or act like
# 	43. make.v.43: consider as being
# 	44. make.v.44: calculate as being
# 	45. make.v.45: cause to be enjoyable or pleasurable
# 	46. make.v.46: favor the development of
# 	47. make.v.47: develop into
# 	48. make.v.48: behave in a certain way
# 	49. make.v.49: eliminate urine
#
# 	Synsets for 'clear' (POS: ADJ):
# 	1. clear.a.01: readily apparent to the mind
# 	2. clear.s.02: free from confusion or doubt
# 	3. clear.s.03: affording free passage or view
# 	4. clear.a.04: allowing light to pass through
# 	5. clear.s.05: free from contact or proximity or connection
# 	6. clear.s.06: characterized by freedom from troubling thoughts (especially guilt)
# 	7. clean.s.03: (of sound or color) free from anything that dulls or dims
# 	8. clear.s.08: (especially of a title) free from any encumbrance or limitation that presents a question of fact or law
# 	9. clear.s.09: clear and distinct to the senses; easily perceptible
# 	10. well-defined.a.02: accurately stated or described
# 	11. clear.a.11: free from clouds or mist or haze
# 	12. clean.s.02: free of restrictions or qualifications
# 	13. clear.s.13: free from flaw or blemish or impurity
# 	14. clear.s.14: clear of charges or deductions
# 	15. clear.s.15: easily deciphered
# 	16. absolved.s.01: freed from any question of guilt
# 	17. clear.s.17: characterized by ease and quickness in perceiving
#
# 	Synsets for 'over' (POS: ADV):
# 	1. over.r.01: at or to a point across intervening space etc.
# 	2. over.r.02: throughout an area
# 	3. over.r.03: throughout a period of time
# 	4. over.r.04: beyond the top or upper surface or edge; forward from an upright position
# 	5. all_over.r.01: over the entire area
#
# 	Synsets for 'hosted' (POS: VERB):
# 	1. host.v.01: be the host of or for
#
# 	Synsets for 'pledged' (POS: VERB):
# 	1. pledge.v.01: promise solemnly and formally
# 	2. pledge.v.02: pay (an amount of money) as a contribution to a charity or service, especially at regular intervals
# 	3. toast.v.02: propose a toast to
# 	4. pledge.v.04: give as a guarantee
# 	5. pledge.v.05: bind or secure by a pledge
#
# 	Synsets for 'unstinting' (POS: ADJ):
# 	1. lavish.s.01: very generous
#
# 	Synsets for 'autocratic' (POS: ADJ):
# 	1. autocratic.s.01: offensively self-assured or given to exercising usually unwarranted power
# 	2. authoritarian.s.01: characteristic of an absolute ruler or absolute rule; having absolute sovereignty
# Sentence 3:
#
# 	Synsets for 'said' (POS: VERB):
# 	1. state.v.01: express in words
# 	2. allege.v.01: report or maintain
# 	3. suppose.v.01: express a supposition
# 	4. read.v.02: have or contain a certain wording or form
# 	5. order.v.01: give instructions to or direct somebody to do something with authority
# 	6. pronounce.v.01: speak, pronounce, or utter in a certain way
# 	7. say.v.07: communicate or express nonverbally
# 	8. say.v.08: utter aloud
# 	9. say.v.09: state as one's opinion or judgement; declare
# 	10. say.v.10: recite or repeat a fixed text
# 	11. say.v.11: indicate
#
# 	Synsets for 'sat' (POS: VERB):
# 	1. sit.v.01: be seated
# 	2. sit.v.02: be around, often idly or without specific purpose
# 	3. sit_down.v.01: take a seat
# 	4. sit.v.04: be in session
# 	5. model.v.03: assume a posture as for artistic purposes
# 	6. ride.v.01: sit and travel on the back of animal, usually while controlling its motions
# 	7. sit.v.07: be located or situated somewhere
# 	8. baby-sit.v.02: work or act as a baby-sitter
# 	9. seat.v.01: show to a seat; assign a seat for
# 	10. sit.v.10: serve in a specific professional capacity
# Sentence 4:
#
# 	Synsets for 'just' (POS: ADV):
# 	1. merely.r.01: and nothing more
# 	2. precisely.r.01: indicating exactness or preciseness
# 	3. just.r.03: only a moment ago
# 	4. just.r.04: absolutely
# 	5. barely.r.01: only a very short time before; ; ; ; ; - W.B.Yeats
# 	6. just.r.06: exactly at this moment or the moment described
#
# 	Synsets for 'want' (POS: VERB):
# 	1. desire.v.01: feel or have a desire for; want strongly
# 	2. want.v.02: have need of
# 	3. want.v.03: hunt or look for; want for a particular reason
# 	4. want.v.04: wish or demand the presence of
# 	5. want.v.05: be without, lack; be deficient in
#
# 	Synsets for 'let' (POS: VERB):
# 	1. let.v.01: make it possible through a specific action or lack of action for something to happen
# 	2. let.v.02: actively cause something to happen
# 	3. permit.v.01: consent to, give permission
# 	4. get.v.03: cause to move; cause to be in a certain position or condition
# 	5. let.v.05: leave unchanged
# 	6. lease.v.03: grant use or occupation of under a term of contract
#
# 	Synsets for 'know' (POS: VERB):
# 	1. know.v.01: be cognizant or aware of a fact or a specific piece of information; possess knowledge or information about
# 	2. know.v.02: know how to do or perform something
# 	3. know.v.03: be aware of the truth of something; have a belief or faith in something; regard as true beyond any doubt
# 	4. know.v.04: be familiar or acquainted with a person or an object
# 	5. know.v.05: have firsthand knowledge of states, situations, emotions, or sensations
# 	6. acknowledge.v.06: accept (someone) to be what is claimed or accept his power and authority
# 	7. know.v.07: have fixed in the mind
# 	8. sleep_together.v.01: have sexual intercourse with
# 	9. know.v.09: know the nature or character of
# 	10. know.v.10: be able to distinguish, recognize as being different
# 	11. know.v.11: perceive as familiar
#
# 	Synsets for 'was' (POS: VERB):
# 	1. be.v.01: have the quality of being; (copula, used with an adjective or a predicate noun)
# 	2. be.v.02: be identical to; be someone or something
# 	3. be.v.03: occupy a certain position or area; be somewhere
# 	4. exist.v.01: have an existence, be extant
# 	5. be.v.05: happen, occur, take place
# 	6. equal.v.01: be identical or equivalent to
# 	7. constitute.v.01: form or compose
# 	8. be.v.08: work in a specific place, with a specific subject, or in a specific function
# 	9. embody.v.02: represent, as of a character on stage
# 	10. be.v.10: spend or use time
# 	11. be.v.11: have life, be alive
# 	12. be.v.12: to remain unmolested, undisturbed, or uninterrupted -- used only in infinitive form
# 	13. cost.v.01: be priced at
#
# 	Synsets for 'very' (POS: ADV):
# 	1. very.r.01: used as intensifiers; `real' is sometimes used informally for `really'; `rattling' is informal
# 	2. very.r.02: precisely so
#
# 	Synsets for 'much' (POS: ADV):
# 	1. much.r.01: to a great degree or extent
# 	2. much.r.02: very
# 	3. a_lot.r.01: to a very great degree or extent
# 	4. much.r.04: (degree adverb used before a noun phrase) for all practical purposes but not completely
# 	5. much.r.05: frequently or in great quantities
# Sentence 5:
#
# 	Synsets for 'considered' (POS: VERB):
# 	1. see.v.05: deem to be
# 	2. study.v.03: give careful consideration to
# 	3. consider.v.03: take into consideration for exemplifying purposes
# 	4. consider.v.04: show consideration for; take into account
# 	5. consider.v.05: think about carefully; weigh
# 	6. think.v.01: judge or regard; look upon; judge
# 	7. regard.v.02: look at attentively
# 	8. view.v.02: look at carefully; study mentally
# 	9. consider.v.09: regard or treat with consideration, respect, and esteem
#
# 	Synsets for 'distasteful' (POS: ADJ):
# 	1. distasteful.s.01: not pleasing in odor or taste
# 	2. disgusting.s.01: highly offensive; arousing aversion or disgust
#
# 	Synsets for 'shied' (POS: VERB):
# 	1. shy.v.01: start suddenly, as from fright
# 	2. shy.v.02: throw quickly
#
# 	Synsets for 'away' (POS: ADV):
# 	1. away.r.01: from a particular thing or place or position (`forth' is obsolete)
# 	2. away.r.02: from one's possession
# 	3. aside.r.02: out of the way (especially away from one's thoughts)
# 	4. away.r.04: out of existence; ; - H.E.Scudder
# 	5. off.r.02: at a distance in space or time
# 	6. away.r.06: indicating continuing action; continuously or steadily
# 	7. away.r.07: so as to be removed or gotten rid of
# 	8. away.r.08: freely or at will
# 	9. away.r.09: in or into a proper place (especially for storage or safekeeping)
# 	10. away.r.10: in a different direction
# 	11. aside.r.06: in reserve; not for immediate use
#
# 	Synsets for 'signaled' (POS: VERB):
# 	1. sign.v.05: communicate silently and non-verbally by signals or signs
# 	2. bespeak.v.01: be a signal for or a symptom of
#
# 	Synsets for 'sees' (POS: VERB):
# 	1. see.v.01: perceive by sight or have the power to perceive by sight
# 	2. understand.v.02: perceive (an idea or situation) mentally
# 	3. witness.v.02: perceive or be contemporaneous with
# 	4. visualize.v.01: imagine; conceive of; see in one's mind
# 	5. see.v.05: deem to be
# 	6. learn.v.02: get to know or become aware of, usually accidentally
# 	7. watch.v.03: see or watch
# 	8. meet.v.01: come together
# 	9. determine.v.08: find out, learn, or determine with certainty, usually by making an inquiry or other effort
# 	10. see.v.10: be careful or certain to do something; make certain of something
# 	11. see.v.11: go to see for professional or business reasons
# 	12. see.v.12: go to see for a social visit
# 	13. visit.v.01: go to see a place, as for entertainment
# 	14. attend.v.02: take charge of or deal with
# 	15. see.v.15: receive as a specified guest
# 	16. go_steady.v.01: date regularly; have a steady relationship with
# 	17. see.v.17: see and understand, have a good eye
# 	18. see.v.18: deliberate or decide
# 	19. see.v.19: observe as if with an eye
# 	20. examine.v.02: observe, check out, and look over carefully or inspect
# 	21. experience.v.01: go or live through
# 	22. see.v.22: accompany or escort
# 	23. see.v.23: match or meet
# 	24. interpret.v.01: make sense of; assign a meaning to
#
# 	Synsets for 'international' (POS: ADJ):
# 	1. international.a.01: concerning or belonging to all or at least two or more nations
# 	2. external.s.03: from or between other countries
# 	No synsets found for the word: transactional
# Sentence 6:
#
# 	Synsets for 'arrived' (POS: VERB):
# 	1. arrive.v.01: reach a destination; arrive by movement or progress
# 	2. arrive.v.02: succeed in a big way; get to the top
#
# 	Synsets for 'financial' (POS: ADJ):
# 	1. fiscal.a.01: involving financial matters
#
# 	Synsets for 'political' (POS: ADJ):
# 	1. political.a.01: involving or characteristic of politics or parties or politicians; - Daniel Goleman
# 	2. political.a.02: of or relating to your views about social relationships involving authority or power
# 	3. political.a.03: of or relating to the profession of governing
#
# 	Synsets for 'effectively' (POS: ADV):
# 	1. efficaciously.r.01: in an effective manner
# 	2. effectively.r.02: in actuality or reality or fact
#
# 	Synsets for 'got' (POS: VERB):
# 	1. get.v.01: come into the possession of something concrete or abstract
# 	2. become.v.01: enter or assume a certain state or condition
# 	3. get.v.03: cause to move; cause to be in a certain position or condition
# 	4. receive.v.02: receive a specified treatment (abstract)
# 	5. arrive.v.01: reach a destination; arrive by movement or progress
# 	6. bring.v.04: go or come after and bring or take back
# 	7. experience.v.03: go through (mental or physical states or experiences)
# 	8. pay_back.v.02: take vengeance on or get even
# 	9. have.v.17: achieve a point or goal
# 	10. induce.v.02: cause to do; cause to act in a specified manner
# 	11. get.v.11: succeed in catching or seizing, especially after a chase
# 	12. grow.v.08: come to have or undergo a change of (physical features and attributes)
# 	13. contract.v.04: be stricken by an illness, fall victim to an illness
# 	14. get.v.14: communicate with a place or person; establish communication with, as if by telephone
# 	15. make.v.02: give certain properties to something
# 	16. drive.v.11: move into a desired direction of discourse
# 	17. catch.v.18: grasp with the mind or develop an understanding of
# 	18. catch.v.07: attract and fix
# 	19. get.v.19: reach with a blow or hit in a particular spot
# 	20. get.v.20: reach by calculation
# 	21. get.v.21: acquire as a result of some effort or action
# 	22. get.v.22: purchase
# 	23. catch.v.21: perceive by hearing
# 	24. catch.v.22: suffer from the receipt of
# 	25. get.v.25: receive as a retribution or punishment
# 	26. scram.v.01: leave immediately; used usually in the imperative form
# 	27. get.v.27: reach and board
# 	28. get.v.28: irritate
# 	29. get.v.29: evoke an emotional response
# 	30. catch.v.24: apprehend and reproduce accurately
# 	31. draw.v.15: earn or achieve a base by being walked by the pitcher
# 	32. get.v.32: overcome or destroy
# 	33. perplex.v.01: be a mystery or bewildering to
# 	34. get_down.v.07: take the first step or steps in carrying out an action
# 	35. suffer.v.02: undergo (as of injuries and illnesses)
# 	36. beget.v.01: make children
#
# 	Synsets for 'really' (POS: ADV):
# 	1. truly.r.01: in accordance with truth or fact or reality
# 	2. actually.r.01: in actual fact
# 	3. in_truth.r.01: in fact (used as intensifiers or sentence modifiers)
# 	4. very.r.01: used as intensifiers; `real' is sometimes used informally for `really'; `rattling' is informal
#
# 	Synsets for 'wanted' (POS: VERB):
# 	1. desire.v.01: feel or have a desire for; want strongly
# 	2. want.v.02: have need of
# 	3. want.v.03: hunt or look for; want for a particular reason
# 	4. want.v.04: wish or demand the presence of
# 	5. want.v.05: be without, lack; be deficient in
#
# 	Synsets for 'permitted' (POS: VERB):
# 	1. permit.v.01: consent to, give permission
# 	2. let.v.01: make it possible through a specific action or lack of action for something to happen
# 	3. allow.v.10: allow the presence of or allow (an activity) without opposing or prohibiting
#
# 	Synsets for 'record' (POS: VERB):
# 	1. record.v.01: make a record of; set down in permanent form
# 	2. record.v.02: register electronically
# 	3. read.v.08: indicate a certain reading; of gauges and instruments
# 	4. record.v.04: be aware of
# 	5. commemorate.v.03: be or provide a memorial to a person or an event
#
# 	Synsets for 'denied' (POS: VERB):
# 	1. deny.v.01: declare untrue; contradict
# 	2. deny.v.02: refuse to accept or believe
# 	3. deny.v.03: refuse to grant, as of a petition or request
# 	4. deny.v.04: refuse to let have
# 	5. deny.v.05: deny oneself (something); restrain, especially from indulging in some pleasure
# 	6. traverse.v.03: deny formally (an allegation of fact by the opposing party) in a legal suit
# 	7. deny.v.07: refuse to recognize or acknowledge
# Sentence 7:
#
# 	Synsets for 'big' (POS: ADJ):
# 	1. large.a.01: above average in size or number or quantity or magnitude or extent
# 	2. big.s.02: significant
# 	3. bad.s.02: very intense
# 	4. big.s.04: loud and firm
# 	5. big.s.05: conspicuous in position or importance
# 	6. big.s.06: prodigious
# 	7. boastful.s.01: exhibiting self-importance
# 	8. big.s.08: feeling self-importance
# 	9. adult.s.01: (of animals) fully developed
# 	10. big.s.10: marked by intense physical force
# 	11. big.s.11: generous and understanding and tolerant
# 	12. big.s.12: given or giving freely
# 	13. big.s.13: in an advanced stage of pregnancy
#
# 	Synsets for 'just' (POS: ADV):
# 	1. merely.r.01: and nothing more
# 	2. precisely.r.01: indicating exactness or preciseness
# 	3. just.r.03: only a moment ago
# 	4. just.r.04: absolutely
# 	5. barely.r.01: only a very short time before; ; ; ; ; - W.B.Yeats
# 	6. just.r.06: exactly at this moment or the moment described
#
# 	Synsets for 'sought' (POS: VERB):
# 	1. seek.v.01: try to get or reach
# 	2. search.v.01: try to locate or discover, or try to establish the existence of
# 	3. try.v.01: make an effort or attempt
# 	4. seek.v.04: go to or towards
# 	5. seek.v.05: inquire for
#
# 	Synsets for 'said' (POS: VERB):
# 	1. state.v.01: express in words
# 	2. allege.v.01: report or maintain
# 	3. suppose.v.01: express a supposition
# 	4. read.v.02: have or contain a certain wording or form
# 	5. order.v.01: give instructions to or direct somebody to do something with authority
# 	6. pronounce.v.01: speak, pronounce, or utter in a certain way
# 	7. say.v.07: communicate or express nonverbally
# 	8. say.v.08: utter aloud
# 	9. say.v.09: state as one's opinion or judgement; declare
# 	10. say.v.10: recite or repeat a fixed text
# 	11. say.v.11: indicate
# Sentence 8:
#
# 	Synsets for 'first' (POS: ADJ):
# 	1. first.a.01: preceding all others in time or space or degree
# 	2. first.s.02: indicating the beginning unit in a series
# 	3. inaugural.s.02: serving to set in motion
# 	4. beginning.s.01: serving to begin
# 	5. first.s.05: ranking above all others
# 	6. first.a.06: highest in pitch or chief among parts or voices or instruments or orchestra sections
#
# 	Synsets for 'Egyptian' (POS: ADJ):
# 	1. egyptian.a.01: of or relating to or characteristic of Egypt or its people or their language
#
# 	Synsets for 'autocratic' (POS: ADJ):
# 	1. autocratic.s.01: offensively self-assured or given to exercising usually unwarranted power
# 	2. authoritarian.s.01: characteristic of an absolute ruler or absolute rule; having absolute sovereignty
#
# 	Synsets for 'former' (POS: ADJ):
# 	1. former.a.01: referring to the first of two things or persons mentioned (or the earlier one or ones of several)
# 	2. erstwhile.s.01: belonging to some prior time
# 	3. former.s.03: (used especially of persons) of the immediate past
# 	4. early.s.03: belonging to the distant past
#
# 	Synsets for 'then' (POS: ADV):
# 	1. then.r.01: subsequently or soon afterward (often used as sentence connectors)
# 	2. then.r.02: in that case or as a consequence
# 	3. then.r.03: at that time
#
# 	Synsets for 'waning' (POS: VERB):
# 	1. decline.v.04: grow smaller
# 	2. wane.v.02: become smaller
# 	3. wane.v.03: decrease in phase
# 	4. wan.v.01: become pale and sickly
#
# 	Synsets for 'now' (POS: ADV):
# 	1. now.r.01: in the historical present; at this point in the narration of a series of past events
# 	2. nowadays.r.01: in these times; - Nancy Mitford
# 	3. now.r.03: used to preface a command or reproof or request
# 	4. now.r.04: at the present moment
# 	5. immediately.r.01: without delay or hesitation; with no time intervening
# 	6. now.r.06: (prefatory or transitional) indicates a change of subject or activity
# 	7. now.r.07: in the immediate past
#
# 	Synsets for 'viewed' (POS: VERB):
# 	1. see.v.05: deem to be
# 	2. view.v.02: look at carefully; study mentally
# 	3. watch.v.03: see or watch
#
# 	Synsets for 'many' (POS: ADJ):
# 	1. many.a.01: a quantifier that can be used with count nouns and is often preceded by `as' or `too' or `so' or `that'; amounting to a large but indefinite number
#
# 	Synsets for 'relative' (POS: ADJ):
# 	1. relative.a.01: estimated by comparison; not absolute or complete
# 	2. proportional.s.01: properly related in size or degree or other measurable characteristics; usually followed by `to'
# Sentence 9:
#
# 	Synsets for 'pushed' (POS: VERB):
# 	1. push.v.01: move with force,
# 	2. push.v.02: press, drive, or impel (someone) to action or completion of an action
# 	3. advertise.v.02: make publicity for; try to sell (a product)
# 	4. tug.v.02: strive and make an effort to reach a goal
# 	5. push.v.05: press against forcefully without moving
# 	6. push.v.06: approach a certain age or speed
# 	7. crusade.v.01: exert oneself continuously, vigorously, or obtrusively to gain an end or engage in a crusade for a certain cause or person; be an advocate for
# 	8. push.v.08: sell or promote the sale of (illegal goods such as drugs)
# 	9. push.v.09: move strenuously and with effort
# 	10. press.v.11: make strenuous pushing movements during birth to expel the baby
#
# 	Synsets for 'succeeded' (POS: VERB):
# 	1. succeed.v.01: attain success or reach a desired goal
# 	2. succeed.v.02: be the successor (of)
#
# 	Synsets for 'democratic' (POS: ADJ):
# 	1. democratic.a.01: characterized by or advocating or based upon the principles of democracy or social equality; ; ; - George du Maurier
# 	2. democratic.a.02: belong to or relating to the Democratic Party
# 	3. democratic.s.03: representing or appealing to or adapted for the benefit of the people at large
# Sentence 10:
#
# 	Synsets for 'Taking' (POS: VERB):
# 	1. take.v.01: carry out
# 	2. take.v.02: require (time or space)
# 	3. lead.v.01: take somebody somewhere
# 	4. take.v.04: get into one's hands, take physically
# 	5. assume.v.03: take on a certain form, attribute, or aspect
# 	6. take.v.06: interpret something in a certain way; convey a particular meaning or impression
# 	7. bring.v.01: take something or somebody with oneself somewhere
# 	8. take.v.08: take into one's possession
# 	9. take.v.09: travel or go by means of a certain kind of transportation, or a certain route
# 	10. choose.v.01: pick out, select, or choose from a number of alternatives
# 	11. accept.v.02: receive willingly something given or offered
# 	12. fill.v.04: assume, as of positions or roles
# 	13. consider.v.03: take into consideration for exemplifying purposes
# 	14. necessitate.v.01: require as useful, just, or proper
# 	15. take.v.15: experience or feel or submit to
# 	16. film.v.01: make a film or photograph of something
# 	17. remove.v.01: remove something concrete, as by lifting, pushing, or taking off, or remove something abstract
# 	18. consume.v.02: serve oneself to, or consume regularly
# 	19. take.v.19: accept or undergo, often unwillingly
# 	20. take.v.20: make use of or accept for some purpose
# 	21. take.v.21: take by force
# 	22. assume.v.05: occupy or take on
# 	23. accept.v.05: admit into a group or community
# 	24. take.v.24: ascertain or determine by measuring, computing or take a reading from a dial
# 	25. learn.v.04: be a student of a certain subject
# 	26. claim.v.05: take as an undesirable consequence of some event or state of affairs
# 	27. take.v.27: head into a specified direction
# 	28. aim.v.01: point or cause to go (blows, weapons, or objects such as photographic equipment) towards
# 	29. take.v.29: be seized or affected in a specified way
# 	30. carry.v.02: have with oneself; have on one's person
# 	31. lease.v.04: engage for service under a term of contract
# 	32. subscribe.v.05: receive or obtain regularly
# 	33. take.v.33: buy, select
# 	34. take.v.34: to get into a position of having, e.g., safety, comfort
# 	35. take.v.35: have sex with; archaic use
# 	36. claim.v.04: lay claim to; as of an idea
# 	37. accept.v.08: be designed to hold or take
# 	38. contain.v.05: be capable of holding or containing
# 	39. take.v.39: develop a habit
# 	40. drive.v.16: proceed along in a vehicle
# 	41. take.v.41: obtain by winning
# 	42. contract.v.04: be stricken by an illness, fall victim to an illness
#
# 	Synsets for 'popular' (POS: ADJ):
# 	1. popular.a.01: regarded with great favor, approval, or affection especially by the general public
# 	2. popular.s.02: carried on by or for the people (or citizens) at large
# 	3. democratic.s.03: representing or appealing to or adapted for the benefit of the people at large
# 	4. popular.s.04: (of music or art) new and of general appeal (especially among young people)
#
# 	Synsets for 'later' (POS: ADV):
# 	1. subsequently.r.01: happening at a time subsequent to a reference time
# 	2. by_and_by.r.01: at some eventual time in the future
# 	3. later.r.03: comparative of the adverb `late'
#
# 	Synsets for 'led' (POS: VERB):
# 	1. lead.v.01: take somebody somewhere
# 	2. leave.v.07: have as a result or residue
# 	3. lead.v.03: tend to or result in
# 	4. lead.v.04: travel in front of; go in advance of others
# 	5. lead.v.05: cause to undertake a certain action
# 	6. run.v.03: stretch out over a distance, space, time, or scope; run or extend between two points or beyond a certain point
# 	7. head.v.02: be in charge of
# 	8. lead.v.08: be ahead of others; be the first
# 	9. contribute.v.03: be conducive to
# 	10. conduct.v.02: lead, as in the performance of a composition
# 	11. go.v.25: lead, extend, or afford access
# 	12. precede.v.04: move ahead (of others) in time or space
# 	13. run.v.23: cause something to pass or lead somewhere
# 	14. moderate.v.01: preside over
#
# 	Synsets for 'then' (POS: ADV):
# 	1. then.r.01: subsequently or soon afterward (often used as sentence connectors)
# 	2. then.r.02: in that case or as a consequence
# 	3. then.r.03: at that time
#
# 	Synsets for 'took' (POS: VERB):
# 	1. take.v.01: carry out
# 	2. take.v.02: require (time or space)
# 	3. lead.v.01: take somebody somewhere
# 	4. take.v.04: get into one's hands, take physically
# 	5. assume.v.03: take on a certain form, attribute, or aspect
# 	6. take.v.06: interpret something in a certain way; convey a particular meaning or impression
# 	7. bring.v.01: take something or somebody with oneself somewhere
# 	8. take.v.08: take into one's possession
# 	9. take.v.09: travel or go by means of a certain kind of transportation, or a certain route
# 	10. choose.v.01: pick out, select, or choose from a number of alternatives
# 	11. accept.v.02: receive willingly something given or offered
# 	12. fill.v.04: assume, as of positions or roles
# 	13. consider.v.03: take into consideration for exemplifying purposes
# 	14. necessitate.v.01: require as useful, just, or proper
# 	15. take.v.15: experience or feel or submit to
# 	16. film.v.01: make a film or photograph of something
# 	17. remove.v.01: remove something concrete, as by lifting, pushing, or taking off, or remove something abstract
# 	18. consume.v.02: serve oneself to, or consume regularly
# 	19. take.v.19: accept or undergo, often unwillingly
# 	20. take.v.20: make use of or accept for some purpose
# 	21. take.v.21: take by force
# 	22. assume.v.05: occupy or take on
# 	23. accept.v.05: admit into a group or community
# 	24. take.v.24: ascertain or determine by measuring, computing or take a reading from a dial
# 	25. learn.v.04: be a student of a certain subject
# 	26. claim.v.05: take as an undesirable consequence of some event or state of affairs
# 	27. take.v.27: head into a specified direction
# 	28. aim.v.01: point or cause to go (blows, weapons, or objects such as photographic equipment) towards
# 	29. take.v.29: be seized or affected in a specified way
# 	30. carry.v.02: have with oneself; have on one's person
# 	31. lease.v.04: engage for service under a term of contract
# 	32. subscribe.v.05: receive or obtain regularly
# 	33. take.v.33: buy, select
# 	34. take.v.34: to get into a position of having, e.g., safety, comfort
# 	35. take.v.35: have sex with; archaic use
# 	36. claim.v.04: lay claim to; as of an idea
# 	37. accept.v.08: be designed to hold or take
# 	38. contain.v.05: be capable of holding or containing
# 	39. take.v.39: develop a habit
# 	40. drive.v.16: proceed along in a vehicle
# 	41. take.v.41: obtain by winning
# 	42. contract.v.04: be stricken by an illness, fall victim to an illness
# Sentence 11:
#
# 	Synsets for 'just' (POS: ADV):
# 	1. merely.r.01: and nothing more
# 	2. precisely.r.01: indicating exactness or preciseness
# 	3. just.r.03: only a moment ago
# 	4. just.r.04: absolutely
# 	5. barely.r.01: only a very short time before; ; ; ; ; - W.B.Yeats
# 	6. just.r.06: exactly at this moment or the moment described
#
# 	Synsets for 'want' (POS: VERB):
# 	1. desire.v.01: feel or have a desire for; want strongly
# 	2. want.v.02: have need of
# 	3. want.v.03: hunt or look for; want for a particular reason
# 	4. want.v.04: wish or demand the presence of
# 	5. want.v.05: be without, lack; be deficient in
#
# 	Synsets for 'say' (POS: VERB):
# 	1. state.v.01: express in words
# 	2. allege.v.01: report or maintain
# 	3. suppose.v.01: express a supposition
# 	4. read.v.02: have or contain a certain wording or form
# 	5. order.v.01: give instructions to or direct somebody to do something with authority
# 	6. pronounce.v.01: speak, pronounce, or utter in a certain way
# 	7. say.v.07: communicate or express nonverbally
# 	8. say.v.08: utter aloud
# 	9. say.v.09: state as one's opinion or judgement; declare
# 	10. say.v.10: recite or repeat a fixed text
# 	11. say.v.11: indicate
#
# 	Synsets for 'have' (POS: VERB):
# 	1. have.v.01: have or possess, either in a concrete or an abstract sense
# 	2. have.v.02: have as a feature
# 	3. experience.v.03: go through (mental or physical states or experiences)
# 	4. own.v.01: have ownership or possession of
# 	5. get.v.03: cause to move; cause to be in a certain position or condition
# 	6. consume.v.02: serve oneself to, or consume regularly
# 	7. have.v.07: have a personal or business relationship with someone
# 	8. hold.v.03: organize or be responsible for
# 	9. have.v.09: have left
# 	10. have.v.10: be confronted with
# 	11. have.v.11: undergo
# 	12. have.v.12: suffer from; be ill with
# 	13. induce.v.02: cause to do; cause to act in a specified manner
# 	14. accept.v.02: receive willingly something given or offered
# 	15. receive.v.01: get something; come into possession of
# 	16. suffer.v.02: undergo (as of injuries and illnesses)
# 	17. have.v.17: achieve a point or goal
# 	18. give_birth.v.01: cause to be born
# 	19. take.v.35: have sex with; archaic use
#
# 	Synsets for 'great' (POS: ADJ):
# 	1. great.s.01: relatively large in size or number or extent; larger than others of its kind
# 	2. great.s.02: of major significance or importance
# 	3. great.s.03: remarkable or out of the ordinary in degree or magnitude or effect
# 	4. bang-up.s.01: very good
# 	5. capital.s.03: uppercase
# 	6. big.s.13: in an advanced stage of pregnancy
#
# 	Synsets for 'told' (POS: VERB):
# 	1. state.v.01: express in words
# 	2. tell.v.02: let something be known
# 	3. tell.v.03: narrate or give a detailed account of
# 	4. order.v.01: give instructions to or direct somebody to do something with authority
# 	5. tell.v.05: discern or comprehend
# 	6. assure.v.02: inform positively and with certainty and confidence
# 	7. tell.v.07: give evidence
# 	8. distinguish.v.01: mark as different
# Sentence 12:
#
# 	Synsets for 'responded' (POS: VERB):
# 	1. react.v.01: show a response or a reaction to something
# 	2. answer.v.01: react verbally
# 	3. respond.v.03: respond favorably or as hoped
# 	No synsets found for the word: kind
#
# 	Synsets for 'sometimes' (POS: ADV):
# 	1. sometimes.r.01: on certain occasions or in certain cases but not always
#
# 	Synsets for 'mimicking' (POS: VERB):
# 	1. mimic.v.01: imitate (a person or manner), especially for satirical effect
# 	No synsets found for the word: Trumpian
# Sentence 13:
#
# 	Synsets for 'long' (POS: ADV):
# 	1. long.r.01: for an extended time or at a distant time
# 	2. long.r.02: for an extended distance
#
# 	Synsets for 'crucial' (POS: ADJ):
# 	1. crucial.a.01: of extreme importance; vital to the resolution of a crisis
# 	2. crucial.s.02: having crucial relevance
# 	3. all-important.s.01: of the greatest importance
#
# 	Synsets for 'American' (POS: ADJ):
# 	1. american.a.01: of or relating to the United States of America or its people or language or culture
# 	2. american.a.02: of or relating to or characteristic of the continents and islands of the Americas
#
# 	Synsets for 'seems' (POS: VERB):
# 	1. look.v.02: give a certain impression or have a certain outward aspect
# 	2. appear.v.04: seem to be true, probable, or apparent
# 	3. seem.v.03: appear to exist
# 	4. seem.v.04: appear to one's own mind or opinion
#
# 	Synsets for 'mirror' (POS: VERB):
# 	1. mirror.v.01: reflect as if in a mirror
# 	2. mirror.v.02: reflect or resemble
# 	No synsets found for the word: fellow
#
# 	Synsets for 'tough' (POS: ADJ):
# 	1. tough.a.01: not given to gentleness or sentimentality
# 	2. rugged.s.04: very difficult; severely testing stamina or resolution
# 	3. tough.a.03: physically toughened
# 	4. sturdy.s.03: substantially made or constructed
# 	5. ruffianly.s.01: violent and lawless
# 	6. bad.s.03: feeling physical discomfort or pain (`tough' is occasionally used colloquially for `bad')
# 	7. tough.a.07: resistant to cutting or chewing
# 	8. hard.s.11: unfortunate or hard to bear
# 	9. baffling.s.01: making great mental demands; hard to comprehend or solve or believe
# Sentence 14:
#
# 	Synsets for 'first' (POS: ADJ):
# 	1. first.a.01: preceding all others in time or space or degree
# 	2. first.s.02: indicating the beginning unit in a series
# 	3. inaugural.s.02: serving to set in motion
# 	4. beginning.s.01: serving to begin
# 	5. first.s.05: ranking above all others
# 	6. first.a.06: highest in pitch or chief among parts or voices or instruments or orchestra sections
#
# 	Synsets for 'running' (POS: VERB):
# 	1. run.v.01: move fast by using one's feet, with one foot off the ground at any given time
# 	2. scat.v.01: flee; take to one's heels; cut and run
# 	3. run.v.03: stretch out over a distance, space, time, or scope; run or extend between two points or beyond a certain point
# 	4. operate.v.01: direct or control; projects, businesses, etc.
# 	5. run.v.05: have a particular form
# 	6. run.v.06: move along, of liquids
# 	7. function.v.01: perform as expected when applied
# 	8. range.v.01: change or be different within limits
# 	9. campaign.v.01: run, stand, or compete for an office or a position
# 	10. play.v.18: cause to emit recorded audio or video
# 	11. run.v.11: move about freely and without restraint, or act as if running around in an uncontrolled way
# 	12. tend.v.01: have a tendency or disposition to do or be something; be inclined
# 	13. run.v.13: be operating, running or functioning
# 	14. run.v.14: change from one state to another
# 	15. run.v.15: cause to perform
# 	16. run.v.16: be affected by; be subjected to
# 	17. prevail.v.03: continue to exist
# 	18. run.v.18: occur persistently
# 	19. run.v.19: carry out a process or program, as on a computer or a machine
# 	20. carry.v.15: include as the content; broadcast or publicize
# 	21. run.v.21: carry out
# 	22. guide.v.05: pass over, across, or through
# 	23. run.v.23: cause something to pass or lead somewhere
# 	24. run.v.24: make without a miss
# 	25. run.v.25: deal in illegally, such as arms or liquor
# 	26. run.v.26: cause an animal to move fast
# 	27. run.v.27: be diffused
# 	28. run.v.28: sail before the wind
# 	29. run.v.29: cover by running; run a certain distance
# 	30. run.v.30: extend or continue for a certain period of time
# 	31. run.v.31: set animals loose to graze
# 	32. run.v.32: keep company
# 	33. run.v.33: run with the ball; in such sports as football
# 	34. run.v.34: travel rapidly, by any (unspecified) means
# 	35. ply.v.03: travel a route regularly
# 	36. hunt.v.01: pursue for food or sport (as of wild animals)
# 	37. race.v.02: compete in a race
# 	38. move.v.13: progress by being changed
# 	39. melt.v.01: reduce or cause to be reduced from a solid to a liquid state, usually by heating
# 	40. ladder.v.01: come unraveled or undone as if by snagging
# 	41. run.v.41: become undone
#
# 	Synsets for 'hailed' (POS: VERB):
# 	1. acclaim.v.01: praise vociferously
# 	2. hail.v.02: be a native of
# 	3. hail.v.03: call for
# 	4. hail.v.04: greet enthusiastically or joyfully
# 	5. hail.v.05: precipitate as small ice particles
#
# 	Synsets for 'fantastic' (POS: ADJ):
# 	1. antic.s.01: ludicrously odd
# 	2. fantastic.s.02: extraordinarily good or great ; used especially as intensifiers
# 	3. fantastic.s.03: fanciful and unrealistic; foolish
# 	4. fantastic.s.04: existing in fancy only; - Nathaniel Hawthorne
# 	5. fantastic.s.05: extravagantly fanciful in design, construction, appearance
#
# 	Synsets for 'spoke' (POS: VERB):
# 	1. talk.v.02: express in speech
# 	2. talk.v.01: exchange thoughts; talk with
# 	3. speak.v.03: use language
# 	4. address.v.02: give a speech to
# 	5. speak.v.05: make a characteristic or natural sound
#
# 	Synsets for 'admiringly' (POS: ADV):
# 	1. admiringly.r.01: with admiration
# 	No synsets found for the word: fisted
# Sentence 15:
#
# 	Synsets for 'rejected' (POS: VERB):
# 	1. reject.v.01: refuse to accept or acknowledge
# 	2. refuse.v.02: refuse to accept
# 	3. disapprove.v.02: deem wrong or inappropriate
# 	4. reject.v.04: reject with contempt
# 	5. resist.v.05: resist immunologically the introduction of some foreign tissue or organ
# 	6. reject.v.06: refuse entrance or membership
# 	7. rule_out.v.03: dismiss from consideration or a contest
#
# 	Synsets for 'rules' (POS: VERB):
# 	1. govern.v.03: exercise authority over; as of nations
# 	2. rule.v.02: decide with authority
# 	3. predominate.v.01: be larger in number, quantity, power, status or importance
# 	4. rule.v.04: decide on and make a declaration about
# 	5. rule.v.05: have an affinity with; of signs of the zodiac
# 	6. rule.v.06: mark or draw with a ruler
# 	7. rule.v.07: keep in check
# Sentence 16:
#
# 	Synsets for 'Italian' (POS: ADJ):
# 	1. italian.a.01: of or pertaining to or characteristic of Italy or its people or culture or language
#
# 	Synsets for 'found' (POS: VERB):
# 	1. establish.v.01: set up or found
# 	2. establish.v.02: set up or lay the groundwork for
# 	3. establish.v.08: use as a basis for; found on
# 	4. find.v.01: come upon, as if by accident; meet with
# 	5. detect.v.01: discover or determine the existence, presence, or fact of
# 	6. find.v.03: come upon after searching; find the location of something that was missed or lost
# 	7. determine.v.01: establish after a calculation, investigation, experiment, survey, or study
# 	8. find.v.05: come to believe on the basis of emotion, intuitions, or indefinite grounds
# 	9. witness.v.02: perceive or be contemporaneous with
# 	10. line_up.v.02: get something or somebody for a specific purpose
# 	11. discover.v.03: make a discovery, make a new finding
# 	12. discover.v.04: make a discovery
# 	13. find.v.10: obtain through effort or management
# 	14. rule.v.04: decide on and make a declaration about
# 	15. receive.v.02: receive a specified treatment (abstract)
# 	16. find.v.13: perceive oneself to be in a certain condition or place
# 	17. recover.v.01: get or find back; recover the use of
# 	18. find.v.15: succeed in reaching; arrive at
# 	19. find_oneself.v.01: accept and make use of one's personality, abilities, and situation
#
# 	Synsets for 'dead' (POS: ADJ):
# 	1. dead.a.01: no longer having or seeming to have or expecting to have life
# 	2. dead.a.02: not showing characteristics of life especially the capacity to sustain life; no longer exerting force or having energy or heat
# 	3. all_in.s.01: very tired
# 	4. dead.s.04: unerringly accurate
# 	5. dead.s.05: physically inactive
# 	6. dead.s.06: (followed by `to') not showing human feeling or sensitivity; unresponsive
# 	7. dead.s.07: devoid of physical sensation; numb
# 	8. dead.s.08: lacking acoustic resonance
# 	9. dead.s.09: not yielding a return
# 	10. dead.s.10: not circulating or flowing
# 	11. dead.s.11: not surviving in active use
# 	12. dead.s.12: lacking resilience or bounce
# 	13. dead.s.13: out of use or operation because of a fault or breakdown
# 	14. dead.s.14: no longer having force or relevance
# 	15. dead.s.15: complete
# 	16. dead.s.16: drained of electric charge; discharged
# 	17. dead.s.17: devoid of activity
#
# 	Synsets for 'last' (POS: ADJ):
# 	1. last.s.01: immediately past
# 	2. last.a.02: coming after all others in time or space or degree or being the only one remaining
# 	3. concluding.s.01: occurring at or forming an end or termination
# 	4. last.s.04: most unlikely or unsuitable
# 	5. last.s.05: occurring at the time of death
# 	6. final.s.02: conclusive in a process or progression
# 	7. last.s.07: highest in extent or degree
# 	8. final.s.03: not to be altered or undone
# 	9. last.s.09: lowest in rank or importance
#
# 	Synsets for 'held' (POS: VERB):
# 	1. keep.v.01: keep in a certain state, position, or activity; e.g.,
# 	2. hold.v.02: have or hold in one's hands or grip
# 	3. hold.v.03: organize or be responsible for
# 	4. have.v.01: have or possess, either in a concrete or an abstract sense
# 	5. deem.v.01: keep in mind or convey as a conviction or view
# 	6. harbor.v.01: maintain (a theory, thoughts, or feelings)
# 	7. restrain.v.03: to close within bounds, limit or hold back from movement
# 	8. retain.v.03: secure and keep for possible future use or application
# 	9. bear.v.11: have rightfully; of rights, titles, and offices
# 	10. hold.v.10: be the physical support of; carry the weight of
# 	11. hold.v.11: contain or hold; have within
# 	12. accommodate.v.04: have room for; hold without crowding
# 	13. hold.v.13: remain in a certain state, position, or condition
# 	14. hold.v.14: support or hold in a certain manner
# 	15. prevail.v.02: be valid, applicable, or true
# 	16. hold.v.16: assert or affirm
# 	17. hold.v.17: have as a major characteristic
# 	18. contain.v.05: be capable of holding or containing
# 	19. reserve.v.04: arrange for and reserve (something for someone else) in advance
# 	20. defend.v.03: protect against a challenge or attack
# 	21. oblige.v.02: bind by an obligation; cause to be indebted
# 	22. hold.v.22: hold the attention of
# 	23. hold.v.23: remain committed to
# 	24. defy.v.01: resist or confront with resistance
# 	25. apply.v.02: be pertinent or relevant or applicable
# 	26. hold.v.26: stop dealing with
# 	27. control.v.02: lessen the intensity of; temper; hold in restraint; hold or keep within limits
# 	28. hold.v.28: keep from departing
# 	29. hold.v.29: take and maintain control over, often by violent means
# 	30. halt.v.01: cause to stop
# 	31. hold.v.31: cover as for protection against noise or smell
# 	32. carry.v.33: drink alcohol without showing ill effects
# 	33. hold.v.33: aim, point, or direct
# 	34. declare.v.04: declare to be
# 	35. agree.v.01: be in accord; be in agreement
# 	36. hold.v.36: keep from exhaling or expelling
#
# 	Synsets for 'press' (POS: VERB):
# 	1. press.v.01: exert pressure or force to or upon
# 	2. urge.v.01: force or impel in an indicated direction
# 	3. weigh.v.05: to be oppressive or burdensome; ,
# 	4. press.v.04: place between two surfaces and apply weight or pressure
# 	5. compress.v.02: squeeze or press together
# 	6. press.v.06: crowd closely
# 	7. press.v.07: create by pressing
# 	8. press.v.08: be urgent
# 	9. crusade.v.01: exert oneself continuously, vigorously, or obtrusively to gain an end or engage in a crusade for a certain cause or person; be an advocate for
# 	10. press.v.10: press from a plastic
# 	11. press.v.11: make strenuous pushing movements during birth to expel the baby
# 	12. iron.v.01: press and smooth with a heated iron
# 	13. weight-lift.v.01: lift weights
# 	14. bid.v.03: ask for or request earnestly
#
# 	Synsets for 'longstanding' (POS: ADJ):
# 	1. longstanding.s.01: having existed for a long time
#
# 	Synsets for 'Egyptian' (POS: ADJ):
# 	1. egyptian.a.01: of or relating to or characteristic of Egypt or its people or their language
#
# 	Synsets for 'abducted' (POS: VERB):
# 	1. kidnap.v.01: take away to an undisclosed location against their will and usually in order to extract a ransom
# 	2. abduct.v.02: pull away from the body
#
# 	Synsets for 'tortured' (POS: VERB):
# 	1. torment.v.01: torment emotionally or mentally
# 	2. torture.v.02: subject to torture
#
# 	Synsets for 'killed' (POS: VERB):
# 	1. kill.v.01: cause to die; put to death, usually intentionally or knowingly
# 	2. kill.v.02: thwart the passage of
# 	3. stamp_out.v.01: end or extinguish by forceful means
# 	4. kill.v.04: be fatal
# 	5. kill.v.05: be the source of great pain for
# 	6. kill.v.06: overwhelm with hilarity, pleasure, or admiration
# 	7. kill.v.07: hit with so much force as to make a return impossible, in racket games
# 	8. kill.v.08: hit with great force
# 	9. kill.v.09: deprive of life
# 	10. kill.v.10: cause the death of, without intention
# 	11. toss_off.v.02: drink down entirely
# 	12. kill.v.12: mark for deletion, rub off, or erase
# 	13. kill.v.13: tire out completely
# 	14. kill.v.14: cause to cease operating
# 	15. kill.v.15: destroy a vitally essential quality of or in
#
# 	Synsets for 'probably' (POS: ADV):
# 	1. probably.r.01: with considerable certainty; without much doubt
# 	2. credibly.r.01: easy to believe on the basis of available evidence
# Sentence 17:
#
# 	Synsets for 'said' (POS: VERB):
# 	1. state.v.01: express in words
# 	2. allege.v.01: report or maintain
# 	3. suppose.v.01: express a supposition
# 	4. read.v.02: have or contain a certain wording or form
# 	5. order.v.01: give instructions to or direct somebody to do something with authority
# 	6. pronounce.v.01: speak, pronounce, or utter in a certain way
# 	7. say.v.07: communicate or express nonverbally
# 	8. say.v.08: utter aloud
# 	9. say.v.09: state as one's opinion or judgement; declare
# 	10. say.v.10: recite or repeat a fixed text
# 	11. say.v.11: indicate
#
# 	Synsets for 'identified' (POS: VERB):
# 	1. identify.v.01: recognize as being; establish the identity of someone or something
# 	2. name.v.02: give the name or identifying characteristics of; refer to by name or some other identifying characteristic property
# 	3. identify.v.03: consider (oneself) as similar to somebody else
# 	4. identify.v.04: conceive of as united or associated
# 	5. identify.v.05: identify as in botany or biology, for example
# 	6. identify.v.06: consider to be equal or the same
#
# 	Synsets for 'high' (POS: ADV):
# 	1. high.r.01: at a great altitude
# 	2. high.r.02: in or to a high position, amount, or degree
# 	3. high.r.03: in a rich manner
# 	4. high.r.04: far up toward the source
#
# 	Synsets for 'ranking' (POS: VERB):
# 	1. rank.v.01: take or have a position relative to others
# 	2. rate.v.01: assign a rank or rating to
# 	3. rank.v.03: take precedence or surpass others in rank
#
# 	Synsets for 'Egyptian' (POS: ADJ):
# 	1. egyptian.a.01: of or relating to or characteristic of Egypt or its people or their language
#
# 	Synsets for 'national' (POS: ADJ):
# 	1. national.a.01: of or relating to or belonging to a nation or country
# 	2. national.a.02: limited to or in the interests of a particular nation
# 	3. national.a.03: concerned with or applicable to or belonging to an entire nation or country
# 	4. national.s.04: owned or maintained for the public by the national government
# 	5. home.s.03: inside the country
# ...
# 	26. scram.v.01: leave immediately; used usually in the imperative form
# 	27. get.v.27: reach and board
# 	28. get.v.28: irritate
# 	29. get.v.29: evoke an emotional response
# 	30. catch.v.24: apprehend and reproduce accurately
# 	31. draw.v.15: earn or achieve a base by being walked by the pitcher
# 	32. get.v.32: overcome or destroy
# 	33. perplex.v.01: be a mystery or bewildering to
# 	34. get_down.v.07: take the first step or steps in carrying out an action
# 	35. suffer.v.02: undergo (as of injuries and illnesses)
# 	36. beget.v.01: make children
#
# 	Synsets for 'fight' (POS: VERB):
# 	1. contend.v.06: be engaged in a fight; carry on a fight
# 	2. fight.v.02: fight against or resist strongly
# 	3. fight.v.03: make a strenuous or labored effort
# 	4. crusade.v.01: exert oneself continuously, vigorously, or obtrusively to gain an end or engage in a crusade for a certain cause or person; be an advocate for
#
# 	Synsets for 'radical' (POS: ADJ):
# 	1. extremist.s.01: (used of opinions and actions) far beyond the norm
# 	2. revolutionary.s.01: markedly new or introducing radical change
# 	3. radical.s.03: arising from or going to the root or source
# 	4. radical.a.04: of or relating to or constituting a linguistic root
# 	5. radical.a.05: especially of leaves; located at the base of a plant or stem; especially arising directly from the root or rootstock or a root-like stem
#
# 	Synsets for 'giving' (POS: VERB):
# 	1. give.v.01: cause to have, in the abstract sense or physical sense
# 	2. yield.v.01: be the cause or source of
# 	3. give.v.03: transfer possession of something concrete or abstract to somebody
# 	4. give.v.04: convey or reveal information
# 	5. give.v.05: convey, as of a compliment, regards, attention, etc.; bestow
# 	6. hold.v.03: organize or be responsible for
# 	7. give.v.07: convey or communicate; of a smile, a look, a physical gesture
# 	8. give.v.08: give as a present; make a gift of
# 	9. give.v.09: cause to happen or be responsible for
# 	10. give.v.10: dedicate
# 	11. render.v.04: give or supply
# 	12. impart.v.01: transmit (knowledge or skills)
# 	13. establish.v.05: bring about
# 	14. give.v.14: leave with; give temporarily
# 	15. give.v.15: emit or utter
# 	16. sacrifice.v.01: endure the loss of
# 	17. pass.v.05: place into the hands or custody of
# 	18. give.v.18: give entirely to a specific person, activity, or cause
# 	19. give.v.19: give (as medicine)
# 	20. give.v.20: give or convey physically
# 	21. give.v.21: bestow
# 	22. grant.v.05: bestow, especially officially
# 	23. move_over.v.01: move in order to make room for someone for something
# 	24. feed.v.02: give food to
# 	25. contribute.v.02: contribute to some cause
# 	26. collapse.v.01: break down, literally or metaphorically
# 	27. give.v.27: estimate the duration or outcome of something
# 	28. give.v.28: execute and deliver
# 	29. give.v.29: deliver in exchange or recompense
# 	30. afford.v.04: afford access to
# 	31. give.v.31: present to view
# 	32. give.v.32: perform for an audience
# 	33. give.v.33: be flexible under stress of physical force
# 	34. give.v.34: propose
# 	35. give.v.35: accord by verdict
# 	36. give.v.36: manifest or show
# 	37. give.v.37: offer in good faith
# 	38. give.v.38: submit for consideration, judgment, or use
# 	39. give.v.39: guide or direct, as by behavior of persuasion
# 	40. give.v.40: allow to have or take
# 	41. give.v.41: inflict as a punishment
# 	42. give.v.42: occur
# 	43. give.v.43: consent to engage in sexual intercourse with a man
# 	44. give.v.44: proffer (a body part)
#
# 	Synsets for 'more' (POS: ADJ):
# 	1. more.a.01: (comparative of `much' used with mass nouns) a quantifier meaning greater in size or amount or extent or degree
# 	2. more.a.02: (comparative of `many' used with count nouns) quantifier meaning greater in number
#
# 	Synsets for 'help' (POS: VERB):
# 	1. help.v.01: give help or assistance; be of service
# 	2. help.v.02: improve the condition of
# 	3. help.v.03: be of use
# 	4. help_oneself.v.01: abstain from doing; always used with a negative
# 	5. serve.v.05: help to some food; help with food or drink
# 	6. help.v.06: contribute to the furtherance of
# 	7. avail.v.03: take or use
# 	8. help.v.08: improve; change for the better
#
# 	Synsets for 'said' (POS: VERB):
# 	1. state.v.01: express in words
# 	2. allege.v.01: report or maintain
# 	3. suppose.v.01: express a supposition
# 	4. read.v.02: have or contain a certain wording or form
# 	5. order.v.01: give instructions to or direct somebody to do something with authority
# 	6. pronounce.v.01: speak, pronounce, or utter in a certain way
# 	7. say.v.07: communicate or express nonverbally
# 	8. say.v.08: utter aloud
# 	9. say.v.09: state as one's opinion or judgement; declare
# 	10. say.v.10: recite or repeat a fixed text
# 	11. say.v.11: indicate
#
# 	Synsets for 'sharply' (POS: ADV):
# 	1. aggressively.r.01: in an aggressive manner
# 	2. sharply.r.02: in a well delineated manner
# 	3. sharply.r.03: changing suddenly in direction and degree
# 	4. precipitously.r.01: very suddenly and to a great degree
#
# 	Synsets for 'critical' (POS: ADJ):
# 	1. critical.a.01: marked by a tendency to find and call attention to errors and flaws
# 	2. critical.a.02: at or of a point at which a property or phenomenon suffers an abrupt change especially having enough mass to sustain a chain reaction
# 	3. critical.a.03: characterized by careful evaluation and judgment
# 	4. critical.s.04: urgently needed; absolutely necessary
# 	5. critical.s.05: forming or having the nature of a turning point or crisis
# 	6. critical.a.06: being in or verging on a state of crisis or emergency
# 	7. critical.a.07: of or involving or characteristic of critics or criticism
# Sentence 24:
#
# 	Synsets for 'worry' (POS: VERB):
# 	1. worry.v.01: be worried, concerned, anxious, troubled, or uneasy
# 	2. worry.v.02: be concerned with
# 	3. worry.v.03: disturb the peace of mind of; afflict with mental agitation or distress
# 	4. concern.v.02: be on the mind of
# 	5. worry.v.05: lacerate by biting
# 	6. worry.v.06: touch or rub constantly
#
# 	Synsets for 'hard' (POS: ADV):
# 	1. hard.r.01: with effort or force or vigor
# 	2. hard.r.02: with firmness
# 	3. hard.r.03: earnestly or intently
# 	4. hard.r.04: causing great damage or hardship
# 	5. hard.r.05: slowly and with difficulty
# 	6. heavily.r.07: indulging excessively
# 	7. hard.r.07: into a solid condition
# 	8. hard.r.08: very near or close in space or time
# 	9. hard.r.09: with pain or distress or bitterness
# 	10. hard.r.10: to the full extent possible; all the way
#
# 	Synsets for 'knuckled' (POS: VERB):
# 	1. knuckle.v.01: press or rub with the knuckles
# 	2. knuckle.v.02: shoot a marble while keeping one's knuckles on the ground
#
# 	Synsets for 'banning' (POS: VERB):
# 	1. ban.v.01: forbid the public distribution of ( a movie or a newspaper)
# 	2. ban.v.02: prohibit especially by legal means or social pressure
# 	3. banish.v.02: ban from a place of residence, as for punishment
# 	4. banish.v.01: expel from a community or group
#
# 	Synsets for 'political' (POS: ADJ):
# 	1. political.a.01: involving or characteristic of politics or parties or politicians; - Daniel Goleman
# 	2. political.a.02: of or relating to your views about social relationships involving authority or power
# 	3. political.a.03: of or relating to the profession of governing
#
# 	Synsets for 'such' (POS: ADJ):
# 	1. such.s.01: of so extreme a degree or extent
#
# 	Synsets for 'as' (POS: ADV):
# 	1. equally.r.01: to the same degree (often followed by `as')
#
# 	Synsets for 'well' (POS: ADV):
# 	1. well.r.01: (often used as a combining form) in a good or proper or satisfactory manner or to a high standard (`good' is a nonstandard dialectal variant for `well')
# 	2. well.r.02: thoroughly or completely; fully; often used as a combining form; ; ; ; ; ,
# 	3. well.r.03: indicating high probability; in all likelihood
# 	4. well.r.04: (used for emphasis or as an intensifier) entirely or fully
# 	5. well.r.05: to a suitable or appropriate extent or degree
# 	6. well.r.06: favorably; with approval
# 	7. well.r.07: to a great extent or degree
# 	8. well.r.08: with great or especially intimate knowledge
# 	9. well.r.09: with prudence or propriety
# 	10. well.r.10: with skill or in a pleasing manner
# 	11. well.r.11: in a manner affording benefit or advantage
# 	12. well.r.12: in financial comfort
# 	13. well.r.13: without unusual distress or resentment; with good humor
#
# 	Synsets for 'fighting' (POS: VERB):
# 	1. contend.v.06: be engaged in a fight; carry on a fight
# 	2. fight.v.02: fight against or resist strongly
# 	3. fight.v.03: make a strenuous or labored effort
# 	4. crusade.v.01: exert oneself continuously, vigorously, or obtrusively to gain an end or engage in a crusade for a certain cause or person; be an advocate for
#
# 	Synsets for 'ultimately' (POS: ADV):
# 	1. ultimately.r.01: as the end result of a succession or process
#
# 	Synsets for 'feed' (POS: VERB):
# 	1. feed.v.01: provide as food
# 	2. feed.v.02: give food to
# 	3. feed.v.03: feed into; supply
# 	4. feed.v.04: introduce continuously
# 	5. feed.v.05: support or promote
# 	6. feed.v.06: take in food; used of animals only
# 	7. feed.v.07: serve as food for; be the food for
# 	8. run.v.06: move along, of liquids
# 	9. prey.v.01: profit from in an exploitatory manner
# 	10. feed.v.10: gratify
# 	11. fertilize.v.01: provide with fertilizers or add nutrients to
# 	12. tip.v.03: give a tip or gratuity to in return for a service, beyond the compensation agreed on
#
# 	Synsets for 'new' (POS: ADJ):
# 	1. new.a.01: not of long duration; having just (or relatively recently) come into being or been made or acquired or discovered
# 	2. fresh.s.04: original and of a kind not seen before
# 	3. raw.s.12: lacking training or experience
# 	4. new.s.04: having no previous example or precedent or parallel
# 	5. new.s.05: other than the former one(s); different
# 	6. new.a.06: unaffected by use or exposure
# 	7. newfangled.s.01: (of a new kind or fashion) gratuitously new
# 	8. new.s.08: in use after medieval times
# 	9. modern.s.05: used of a living language; being the current stage in its development
# 	10. new.s.10: (of crops) harvested at an early stage of development; before complete maturity
# 	11. new.s.11: unfamiliar
#
# 	Synsets for 'blow' (POS: VERB):
# 	1. blow.v.01: exhale hard
# 	2. blow.v.02: be blowing or storming
# 	3. blow.v.03: free of obstruction by blowing air through
# 	4. float.v.01: be in motion due to some air or water current
# 	5. blow.v.05: make a sound as if blown
# 	6. blow.v.06: shape by blowing
# 	7. botch.v.01: make a mess of, destroy or ruin
# 	8. waste.v.01: spend thoughtlessly; throw away
# 	9. blow.v.09: spend lavishly or wastefully on
# 	10. blow.v.10: sound by having air expelled through a tube
# 	11. blow.v.11: play or sound a wind instrument
# 	12. fellate.v.01: provide sexual gratification through oral stimulation
# 	13. blow.v.13: cause air to go in, on, or through
# 	14. blow.v.14: cause to move by means of an air current
# 	15. blow.v.15: spout moist air from the blowhole
# 	16. shove_off.v.01: leave; informal or rude
# 	17. blow.v.17: lay eggs
# 	18. blow.v.18: cause to be revealed and jeopardized
# 	19. boast.v.01: show off
# 	20. blow.v.20: allow to regain its breath
# 	21. blow_out.v.01: melt, break, or become otherwise unusable
# 	22. blow.v.22: burst suddenly
#
# 	Synsets for 'back' (POS: ADV):
# 	1. back.r.01: in or to or toward a former location
# 	2. back.r.02: at or to or toward the back or rear
# 	3. back.r.03: in or to or toward an original condition
# 	4. back.r.04: in or to or toward a past time
# 	5. back.r.05: in reply
# 	6. back.r.06: in repayment or retaliation
# Sentence 25:
#
# 	Synsets for 'authoritarian' (POS: ADJ):
# 	1. authoritarian.s.01: characteristic of an absolute ruler or absolute rule; having absolute sovereignty
# 	2. authoritarian.s.02: expecting unquestioning obedience
#
# 	Synsets for 'struck' (POS: VERB):
# 	1. strike.v.01: deliver a sharp blow, as with the hand, fist, or weapon
# 	2. affect.v.05: have an emotional or cognitive impact upon
# 	3. hit.v.02: hit against; come into sudden contact with
# 	4. strike.v.04: make a strategic, offensive, assault against an enemy, opponent, or a target
# 	5. strike.v.05: indicate (a certain time) by striking
# 	6. hit.v.05: affect or afflict suddenly, usually adversely
# 	7. strike.v.07: stop work in order to press demands
# 	8. fall.v.08: touch or seem as if touching visually or audibly
# 	9. come_to.v.03: attain
# 	10. strike.v.10: produce by manipulating keys or strings of musical instruments, also metaphorically
# 	11. strike.v.11: cause to form (an electric arc) between electrodes of an arc lamp
# 	12. fall_upon.v.01: find unexpectedly
# 	13. strike.v.13: produce by ignition or a blow
# 	14. strike.v.14: remove by erasing or crossing out or as if by drawing a line
# 	15. hit.v.09: cause to experience suddenly
# 	16. hit.v.12: drive something violently into a location
# 	17. assume.v.05: occupy or take on
# 	18. mint.v.01: form by stamping, punching, or printing
# 	19. strickle.v.02: smooth with a strickle
# 	20. strike.v.20: pierce with force
# 	21. strike.v.21: arrive at after reckoning, deliberating, and weighing
#
# 	Synsets for 'seem' (POS: VERB):
# 	1. look.v.02: give a certain impression or have a certain outward aspect
# 	2. appear.v.04: seem to be true, probable, or apparent
# 	3. seem.v.03: appear to exist
# 	4. seem.v.04: appear to one's own mind or opinion
#
# 	Synsets for 'right' (POS: ADJ):
# 	1. right.a.01: being or located on or directed toward the side of the body to the east when facing north
# 	2. correct.a.01: free from error; especially conforming to fact or truth
# 	3. correct.s.02: socially right or correct
# 	4. right.a.04: in conformance with justice or law or morality
# 	5. right.a.05: correct in opinion or judgment
# 	6. proper.s.04: appropriate for a condition or purpose or occasion or a person's character, needs
# 	7. right.a.07: of or belonging to the political or intellectual right
# 	8. right.s.08: in or into a satisfactory condition
# 	9. right.s.09: intended for the right hand
# 	10. correct.s.03: in accord with accepted standards of usage or procedure
# 	11. right.s.11: having the axis perpendicular to the base
# 	12. right.s.12: (of the side of cloth or clothing) facing or intended to face outward
# 	13. good.s.12: most suitable or right for a particular purpose
# 	14. veracious.s.02: precisely accurate
#
# 	Synsets for 'never' (POS: ADV):
# 	1. never.r.01: not ever; at no time in the past or future
# 	2. never.r.02: not at all; certainly not; not in any circumstances
#
# 	Synsets for 'pays' (POS: VERB):
# 	1. pay.v.01: give money, usually in exchange for goods or services
# 	2. give.v.05: convey, as of a compliment, regards, attention, etc.; bestow
# 	3. pay_up.v.01: cancel or discharge a debt
# 	4. yield.v.10: bring in
# 	5. pay.v.05: do or give something to somebody in return
# 	6. give.v.10: dedicate
# 	7. pay.v.07: be worth it
# 	8. pay.v.08: render
# 	9. pay.v.09: bear (a cost or penalty), in recompense for some action
# 	10. pay.v.10: make a compensation for
# 	11. pay.v.11: discharge or settle
#
# 	Synsets for 'long' (POS: ADJ):
# 	1. long.a.01: primarily temporal sense; being or indicating a relatively great or greater than average duration or passage of time or a duration as specified
# 	2. long.a.02: primarily spatial sense; of relatively great or greater than average spatial extension or extension as specified
# 	3. long.s.03: of relatively great height; - Sherwood Anderson
# 	4. retentive.a.01: good at remembering
# 	5. long.a.05: holding securities or commodities in expectation of a rise in prices
# 	6. long.a.06: (of speech sounds or syllables) of relatively long duration
# 	7. long.s.07: involving substantial risk
# 	8. farseeing.s.02: planning prudently for the future
# 	9. long.s.09: having or being more than normal or necessary:
#
# 	Synsets for 'said' (POS: VERB):
# 	1. state.v.01: express in words
# 	2. allege.v.01: report or maintain
# 	3. suppose.v.01: express a supposition
# 	4. read.v.02: have or contain a certain wording or form
# 	5. order.v.01: give instructions to or direct somebody to do something with authority
# 	6. pronounce.v.01: speak, pronounce, or utter in a certain way
# 	7. say.v.07: communicate or express nonverbally
# 	8. say.v.08: utter aloud
# 	9. say.v.09: state as one's opinion or judgement; declare
# 	10. say.v.10: recite or repeat a fixed text
# 	11. say.v.11: indicate
